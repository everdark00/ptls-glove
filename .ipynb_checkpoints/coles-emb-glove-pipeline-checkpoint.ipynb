# %% [markdown]
# ## Setup

# %%
import numpy as np
import pandas as pd
from tqdm.notebook import tqdm
from torch.utils.data import Dataset, DataLoader
import copy
import pickle
import sys
import os

import pytorch_lightning as pl

import logging

sys.path.insert(0, 'C:\\Users\\peter\\anaconda3\\envs\\cv\\Scripts\\ptls-glove')

from functools import partial
from ptls.nn import RnnSeqEncoder, TrxEncoder
from ptls.nn.trx_encoder.trx_encoder_glove import TrxEncoderGlove, TrxEncoderCat, TrxEncoderTrans
from ptls.nn.trx_encoder import GloveEmbedding
from ptls.preprocessing.baseline_discretizer import KDiscretizer, SingleTreeDiscretizer
from ptls.preprocessing.deeptlf.src import DeepTLF
from ptls.frames.coles import CoLESModule
from ptls.data_load.datasets import MemoryMapDataset
from ptls.data_load.iterable_processing import SeqLenFilter
from ptls.frames.coles import ColesDataset
from ptls.frames.coles.split_strategy import SampleSlices
from ptls.frames import PtlsDataModule, TestModule
from ptls.frames.coles.metric import BatchRecallTopK
from ptls.preprocessing.deeptlf import DeepTLFDisc

import ptls
import torch
from torch import nn
from ptls.preprocessing import PandasDataPreprocessor
from sklearn.model_selection import train_test_split
from ptls.data_load.datasets import inference_data_loader
from pytorch_lightning.callbacks.early_stopping import EarlyStopping

# %%
# import os

# if not os.path.exists('data/transactions_train.csv'):
#     ! mkdir -p data
#     ! curl -OL https://storage.yandexcloud.net/ptls-datasets/age-prediction-nti-sbebank-2019.zip
#     ! unzip -j -o age-prediction-nti-sbebank-2019.zip 'data/*.csv' -d data
#     ! mv age-prediction-nti-sbebank-2019.zip data/

# %% [markdown]
# ## Preprocessing rosbank

# %%
def get_df_trx(df_train, df_test):
    COL_EVENT_TIME = 'TRDATETIME'
    df_train = df_train.drop(['PERIOD', 'target_flag', 'target_sum'], axis=1)
    df_test = df_test.drop(['PERIOD'], axis=1)

    df = pd.concat([df_train, df_test], ignore_index=True)

    # event_time mapping
    df['_et_day'] = pd.to_datetime(df[COL_EVENT_TIME].str[:7], format='%d%b%y').astype(np.int64) // 10**9
    df['_et_time'] = (pd.to_datetime(df[COL_EVENT_TIME].str[8:], format='%H:%M:%S').astype(np.int64) // 10**9)

    df['event_time'] = df['_et_day'] + df['_et_time']
    df = df.drop(['_et_day', '_et_time', COL_EVENT_TIME], axis=1)

    df.columns = df.columns.str.lower()
    df['amount'] = df['amount'].astype(float)

    return df

def get_df_target(df_train):
    df_target = df_train.groupby("cl_id")["target_flag"].first().astype({"target_flag": 'int'})

    return pd.DataFrame(df_target)

def split_target(df):
    df['seq_len'] =  np.ceil(np.log(df['seq_len'] / np.log(4))).astype('string')
    df['hash'] = (pd.Series(df.index.astype(str) + "42").apply(hash) / (2 ** 32) + 0.5).values
    df['fold_id'] = df.groupby(["target_flag", 'seq_len'])['hash'].rank(method='first', ascending=True) % 6
    
    df = df.drop(columns = ['hash', 'seq_len'])
    return df

def split_fold(fold_id, df_target, df_trx):
    folds_path = Path(conf_pp.folds_path)
    preproc = PysparkDataPreprocessor(
        col_id=conf_pp.col_client_id,
        col_event_time='event_time',
        event_time_transformation='none',
        cols_category=["mcc", "channel_type", "currency", "trx_category"],
        cols_numerical=['amount'],
        cols_last_item=[conf_pp.col_target],
    )
    df_train_trx = df_trx.merge(df_target, how='left', on=conf_pp.col_client_id).loc[lambda x: x['fold_id'].fillna(-1) != fold_id].drop('fold_id', axis=1)
    df_test_trx = df_trx.merge(df_target.loc[lambda x: x['fold_id'] == fold_id].drop('fold_id', axis=1), how='inner', on=conf_pp.col_client_id)
    df_train_data = preproc.fit_transform(df_train_trx)
    df_test_data = preproc.transform(df_test_trx)
    file_name_train = get_file_name_train(fold_id)
    file_name_test = get_file_name_test(fold_id)
    df_train_data.to_parquet(folds_path / file_name_train, mode='overwrite')
    df_test_data.to_parquet(folds_path / file_name_test, mode='overwrite')
    with open(folds_path / f'preproc_{fold_id}.p', 'wb') as f:
        pickle.dump(preproc, f)
    logger.info(f'Preprocessor[{fold_id}].category_dictionary_sizes={preproc.get_category_dictionary_sizes()}')

    for df_name in [file_name_train, file_name_test]:
        df = pd.read_parquet(folds_path / df_name)
        logger.info(f'{df_name:30} {df.shape}')

    for df_name in [file_name_train, file_name_test]:
        df = pd.read_parquet(folds_path / df_name)
        r_counts = df[conf_pp.col_target].value_counts(dropna=False).to_dict()
        cnt_str = ', '.join([f'{r_counts.get(0, 0):5d} - 0 class', f'{r_counts.get(1, 0):5d} - 1 class'])
        logger.info(f'{df_name:30} {cnt_str}')

# %%
import os
import pandas as pd

data_path = 'data/rosbank'

train = pd.read_csv(os.path.join(data_path, 'train.csv'))
test = pd.read_csv(os.path.join(data_path, 'test.csv'))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 6
#       2 import pandas as pd
#       4 data_path = 'data/rosbank'
# ----> 6 train = pd.read_csv(os.path.join(data_path, 'train.csv'))
#       7 test = pd.read_csv(os.path.join(data_path, 'test.csv'))
#
# File ~/anaconda3/envs/torch/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/anaconda3/envs/torch/lib/python3.10/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/anaconda3/envs/torch/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/anaconda3/envs/torch/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/anaconda3/envs/torch/lib/python3.10/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/rosbank/train.csv'

# %%
df_trx = get_df_trx(train, test)
df_trx = df_trx.fillna("unknown_type")
df_target = get_df_target(train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df_trx = get_df_trx(train, test)
#       2 df_trx = df_trx.fillna("unknown_type")
#       3 df_target = get_df_target(train)
#
# NameError: name 'get_df_trx' is not defined

# %%
df_trx = df_trx.sort_values(by=["cl_id", "event_time"], ascending=True)

# %%
source_data = df_trx.rename({"cl_id" : "client_id", "event_time" : "tr_datetime"})

# %%
source_data.rename(columns = {"cl_id" : "client_id", "event_time" : "tr_datatime"}, inplace=True)

# %%
source_data
# Out:
#          client_id   mcc  channel_type  currency    amount trx_category  \
# 1                0  6011  unknown_type       810  20000.00      DEPOSIT
# 0                0  5200  unknown_type       810   5023.00          POS
# 3                0  5411  unknown_type       810   2031.00          POS
# 4                0  6012  unknown_type       810  36562.00      C2C_OUT
# 2                0  5921  unknown_type       810    767.00          POS
# ...            ...   ...           ...       ...       ...          ...
# 1008299      10216  5411         type1       810    132.13          POS
# 1008293      10216  5691         type1       810   2090.00          POS
# 1008296      10216  5411         type1       810   1259.31          POS
# 1008285      10216  5691         type1       810   1185.00          POS
# 1008290      10216  7922         type1       810   1500.00          POS
#
#          tr_datatime
# 1         -701177753
# 0         -700444800
# 3         -700444800
# 4         -700137936
# 2         -696556800
# ...              ...
# 1008299   -712886400
# 1008293   -712540800
# 1008296   -712540800
# 1008285   -712454400
# 1008290   -712454400
#
# [1008889 rows x 7 columns]

# %% [markdown]
# ## Preprocessing kaggle card-trans

# %%
data_path = 'data/kaggle_nir_card_trans'

data = pd.read_csv(os.path.join(data_path, 'credit_card_transactions.csv'))

# %% [markdown]
# ## Data preproccessing

# %%
myexp = pd.read_csv('../coles_experiments/my_conf_gender.csv').drop(columns=['dataset', 'Unnamed: 0']).rename(columns={'value' : 'my_conf'})
airiexp = pd.read_csv('../coles_experiments/airi_conf_gender.csv').drop(columns=['dataset', 'Unnamed: 0']).rename(columns={'value' : 'repo_conf'})

# %%
myexp.exp_name = list(map(lambda x: x.replace('_myparams', ''), myexp.exp_name))

# %%
airiexp = airiexp.iloc[15:, :]
myexp = pd.concat([myexp.iloc[:9, :], myexp.iloc[15:, :]])

# %%
airiexp
# Out:
#                            exp_name                  metric  repo_conf
# 15    quant_100_dist_common_emb_sum            recall_top_k   0.760667
# 16    quant_100_dist_common_emb_sum  accuracy_lgbm_boosting   0.760791
# 17    quant_100_dist_common_emb_sum  accuracy_random_forest   0.736611
# 18   quant_100_dist_common_emb_mean            recall_top_k   0.653162
# 19   quant_100_dist_common_emb_mean  accuracy_lgbm_boosting   0.705635
# 20   quant_100_dist_common_emb_mean  accuracy_random_forest   0.688449
# 21   st_num_emb_dist_common_emb_cat            recall_top_k   0.707609
# 22   st_num_emb_dist_common_emb_cat  accuracy_lgbm_boosting   0.769185
# 23   st_num_emb_dist_common_emb_cat  accuracy_random_forest   0.745204
# 24  st_num_emb_dist_common_emb_mean            recall_top_k   0.654908
# 25  st_num_emb_dist_common_emb_mean  accuracy_lgbm_boosting   0.734412
# 26  st_num_emb_dist_common_emb_mean  accuracy_random_forest   0.715428
# 27   st_num_emb_dist_common_emb_sum            recall_top_k   0.674185
# 28   st_num_emb_dist_common_emb_sum  accuracy_lgbm_boosting   0.758993
# 29   st_num_emb_dist_common_emb_sum  accuracy_random_forest   0.736011
# 30     deeptlf9_disc_common_emb_cat            recall_top_k   0.720272
# 31     deeptlf9_disc_common_emb_cat  accuracy_lgbm_boosting   0.781775
# 32     deeptlf9_disc_common_emb_cat  accuracy_random_forest   0.756994
# 33     deeptlf9_disc_common_emb_sum            recall_top_k   0.677039
# 34     deeptlf9_disc_common_emb_sum  accuracy_lgbm_boosting   0.748201
# 35     deeptlf9_disc_common_emb_sum  accuracy_random_forest   0.729616
# 36    deeptlf9_disc_common_emb_mean            recall_top_k   0.678296
# 37    deeptlf9_disc_common_emb_mean  accuracy_lgbm_boosting   0.745204
# 38    deeptlf9_disc_common_emb_mean  accuracy_random_forest   0.728617
# 39                         baseline            recall_top_k   0.733833
# 40                         baseline  accuracy_lgbm_boosting   0.769784
# 41                         baseline  accuracy_random_forest   0.743805
# 42    quant_100_dist_common_emb_cat            recall_top_k   0.789840
# 43    quant_100_dist_common_emb_cat  accuracy_lgbm_boosting   0.766787
# 44    quant_100_dist_common_emb_cat  accuracy_random_forest   0.747202

# %%
airiexp.merge(myexp, on=['exp_name', 'metric'], how='inner').dropna().sort_values(by=['exp_name', 'metric'])
# Out:
#                            exp_name                  metric  repo_conf  \
# 25                         baseline  accuracy_lgbm_boosting   0.769784
# 26                         baseline  accuracy_random_forest   0.743805
# 24                         baseline            recall_top_k   0.733833
# 16     deeptlf9_disc_common_emb_cat  accuracy_lgbm_boosting   0.781775
# 17     deeptlf9_disc_common_emb_cat  accuracy_random_forest   0.756994
# 15     deeptlf9_disc_common_emb_cat            recall_top_k   0.720272
# 22    deeptlf9_disc_common_emb_mean  accuracy_lgbm_boosting   0.745204
# 23    deeptlf9_disc_common_emb_mean  accuracy_random_forest   0.728617
# 21    deeptlf9_disc_common_emb_mean            recall_top_k   0.678296
# 19     deeptlf9_disc_common_emb_sum  accuracy_lgbm_boosting   0.748201
# 20     deeptlf9_disc_common_emb_sum  accuracy_random_forest   0.729616
# 18     deeptlf9_disc_common_emb_sum            recall_top_k   0.677039
# 28    quant_100_dist_common_emb_cat  accuracy_lgbm_boosting   0.766787
# 29    quant_100_dist_common_emb_cat  accuracy_random_forest   0.747202
# 27    quant_100_dist_common_emb_cat            recall_top_k   0.789840
# 4    quant_100_dist_common_emb_mean  accuracy_lgbm_boosting   0.705635
# 5    quant_100_dist_common_emb_mean  accuracy_random_forest   0.688449
# 3    quant_100_dist_common_emb_mean            recall_top_k   0.653162
# 1     quant_100_dist_common_emb_sum  accuracy_lgbm_boosting   0.760791
# 2     quant_100_dist_common_emb_sum  accuracy_random_forest   0.736611
# 0     quant_100_dist_common_emb_sum            recall_top_k   0.760667
# 7    st_num_emb_dist_common_emb_cat  accuracy_lgbm_boosting   0.769185
# 8    st_num_emb_dist_common_emb_cat  accuracy_random_forest   0.745204
# 6    st_num_emb_dist_common_emb_cat            recall_top_k   0.707609
# 10  st_num_emb_dist_common_emb_mean  accuracy_lgbm_boosting   0.734412
# 11  st_num_emb_dist_common_emb_mean  accuracy_random_forest   0.715428
# 9   st_num_emb_dist_common_emb_mean            recall_top_k   0.654908
# 13   st_num_emb_dist_common_emb_sum  accuracy_lgbm_boosting   0.758993
# 14   st_num_emb_dist_common_emb_sum  accuracy_random_forest   0.736011
# 12   st_num_emb_dist_common_emb_sum            recall_top_k   0.674185
#
#      my_conf
# 25  0.713429
# 26  0.698241
# 24  0.826907
# 16  0.720624
# 17  0.724021
# 15  0.842015
# 22  0.672662
# 23  0.669265
# 21  0.715735
# 19  0.688249
# 20  0.684053
# 18  0.774050
# 28  0.717026
# 29  0.703837
# 27  0.873293
# 4   0.677458
# 5   0.668665
# 3   0.771600
# 1   0.703837
# 2   0.696643
# 0   0.817560
# 7   0.728417
# 8   0.716627
# 6   0.836570
# 10  0.667266
# 11  0.661271
# 9   0.667659
# 13  0.709832
# 14  0.704836
# 12  0.804552

# %%
myexp
# Out:
#                                       exp_name                  metric  \
# 0                            baseline_myparams            recall_top_k
# 1                            baseline_myparams  accuracy_lgbm_boosting
# 2                            baseline_myparams  accuracy_random_forest
# 3       quant_100_dist_common_emb_myparams_cat            recall_top_k
# 4       quant_100_dist_common_emb_myparams_cat  accuracy_lgbm_boosting
# 5       quant_100_dist_common_emb_myparams_cat  accuracy_random_forest
# 6   quant_num_emb_dist_common_emb_myparams_cat            recall_top_k
# 7   quant_num_emb_dist_common_emb_myparams_cat  accuracy_lgbm_boosting
# 8   quant_num_emb_dist_common_emb_myparams_cat  accuracy_random_forest
# 9      st_num_emb_dist_common_emb_myparams_sum            recall_top_k
# 10     st_num_emb_dist_common_emb_myparams_sum  accuracy_lgbm_boosting
# 11     st_num_emb_dist_common_emb_myparams_sum  accuracy_random_forest
# 12    st_num_emb_dist_common_emb_myparams_mean            recall_top_k
# 13    st_num_emb_dist_common_emb_myparams_mean  accuracy_lgbm_boosting
# 14    st_num_emb_dist_common_emb_myparams_mean  accuracy_random_forest
# 15      quant_100_dist_common_emb_myparams_sum            recall_top_k
# 16      quant_100_dist_common_emb_myparams_sum  accuracy_lgbm_boosting
# 17      quant_100_dist_common_emb_myparams_sum  accuracy_random_forest
# 18     quant_100_dist_common_emb_myparams_mean            recall_top_k
# 19     quant_100_dist_common_emb_myparams_mean  accuracy_lgbm_boosting
# 20     quant_100_dist_common_emb_myparams_mean  accuracy_random_forest
# 21     st_num_emb_dist_common_emb_myparams_cat            recall_top_k
# 22     st_num_emb_dist_common_emb_myparams_cat  accuracy_lgbm_boosting
# 23     st_num_emb_dist_common_emb_myparams_cat  accuracy_random_forest
# 24    st_num_emb_dist_common_emb_myparams_mean            recall_top_k
# 25    st_num_emb_dist_common_emb_myparams_mean  accuracy_lgbm_boosting
# 26    st_num_emb_dist_common_emb_myparams_mean  accuracy_random_forest
# 27     st_num_emb_dist_common_emb_myparams_sum            recall_top_k
# 28     st_num_emb_dist_common_emb_myparams_sum  accuracy_lgbm_boosting
# 29     st_num_emb_dist_common_emb_myparams_sum  accuracy_random_forest
# 30       deeptlf9_disc_common_emb_myparams_cat            recall_top_k
# 31       deeptlf9_disc_common_emb_myparams_cat  accuracy_lgbm_boosting
# 32       deeptlf9_disc_common_emb_myparams_cat  accuracy_random_forest
# 33       deeptlf9_disc_common_emb_myparams_sum            recall_top_k
# 34       deeptlf9_disc_common_emb_myparams_sum  accuracy_lgbm_boosting
# 35       deeptlf9_disc_common_emb_myparams_sum  accuracy_random_forest
# 36      deeptlf9_disc_common_emb_myparams_mean            recall_top_k
# 37      deeptlf9_disc_common_emb_myparams_mean  accuracy_lgbm_boosting
# 38      deeptlf9_disc_common_emb_myparams_mean  accuracy_random_forest
#
#        value
# 0   0.826907
# 1   0.713429
# 2   0.698241
# 3   0.873293
# 4   0.717026
# 5   0.703837
# 6   0.853747
# 7   0.744604
# 8   0.714229
# 9   0.793213
# 10  0.698441
# 11  0.688449
# 12  0.676050
# 13  0.640288
# 14  0.651079
# 15  0.817560
# 16  0.703837
# 17  0.696643
# 18  0.771600
# 19  0.677458
# 20  0.668665
# 21  0.836570
# 22  0.728417
# 23  0.716627
# 24  0.667659
# 25  0.667266
# 26  0.661271
# 27  0.804552
# 28  0.709832
# 29  0.704836
# 30  0.842015
# 31  0.720624
# 32  0.724021
# 33  0.774050
# 34  0.688249
# 35  0.684053
# 36  0.715735
# 37  0.672662
# 38  0.669265

# %%
def prepare_data_age_bins_scenario():
    data_path = '../data/age_bins'

    source_data = pd.read_csv(os.path.join(data_path, 'transactions_train.csv'))

    df_params = {
        "numeric_cols" : ["amount_rur"],
        "cat_cols" : ["small_group"],
        "date_col" : "trans_date",
        "cat_unique" : [],
        "id_col" : "client_id"
    }

    for f in df_params["cat_cols"] + [df_params["date_col"]]:
        df_params["cat_unique"].append(source_data[f].unique().shape[0])

    return source_data, df_params

def prepare_data_gender_scenario():
    data_path = 'data/gender'

    source_data = pd.read_csv(os.path.join(data_path, 'transactions.csv'))
    source_data = source_data.drop(columns=["term_id"])

    source_data.tr_datetime = [int(i.split()[0]) for i in source_data.tr_datetime.values]

    df_params = {
        "numeric_cols" : ["amount"],
        "cat_cols" : ["mcc_code", "tr_type"],
        "cat_unique" : [],
        "date_col" : "tr_datetime",
        "id_col" : "customer_id"
    }

    for f in df_params["cat_cols"] + [df_params["date_col"]]:
        df_params["cat_unique"].append(source_data[f].unique().shape[0])
    
    return source_data, df_params

# %%
source_data, df_params = prepare_data_age_bins_scenario()
targets = pd.read_csv(os.path.join('../data/age_bins', 'train_target.csv'))
source_data.head(2)
# Out:
#    client_id  trans_date  small_group  amount_rur
# 0      33172           6            4      71.463
# 1      33172           6           35      45.017

# %%
preprocessor = PandasDataPreprocessor(
        col_id=df_params['id_col'],
        col_event_time=df_params['date_col'],
        event_time_transformation='none',
        cols_category=df_params['cat_cols'],
        cols_numerical=df_params['numeric_cols'],
        return_records=True,
    )
    
dataset = preprocessor.fit_transform(source_data)

# %%
un = set()
for i in tqdm(dataset):
    un |= set(list(map(lambda x: x.item(), i['small_group'].unique())))
# Out:
#   0%|          | 0/30000 [00:00<?, ?it/s]

# %%
source_data.shape, targets.shape
# Out:
# ((26450577, 4), (30000, 2))

# %%
#primary encoding of bin features with bin categories

data = simple_bin_numeric(source_data, {"amount" : 20})

# %%
EMBED_SIZE = 16

df_params = {'numeric_cols': ['amount_rur'],
     'cat_cols': ['small_group'],
     'date_col': 'trans_date',
     'cat_unique': [202, 730],
     'id_col': 'client_id'}

#best discretizers

disc_quant100 = KDiscretizer(
    f_names = ['amount_rur'],
    k_bins = 100,
    d_type = 'quantile'
)

deeptlf_params9 = DeepTLFDisc({"n_est" : 9,
                  "min_freq" : 2,
                  "features" : df_params['numeric_cols'] + df_params['cat_cols'],
                  "features_to_split" : df_params['numeric_cols'],
                  })

disc_st20 = SingleTreeDiscretizer(
    f_names = ['amount_rur'], 
    target_name = 'bins', 
    target_type = 'classification', 
    k_bins = [20],
)

glove_config1= {"alpha" : 0.75, 
                "x_max" : 100, 
                "embedding_size" : EMBED_SIZE, 
                "num_epochs_train" : 50}

glove_config2= {"alpha" : 0.75, 
                "x_max" : 15000, 
                "embedding_size" : EMBED_SIZE, 
                "num_epochs_train" : 50}

glove_config3= {"alpha" : 1.0, 
                "x_max" : 20000, 
                "embedding_size" : EMBED_SIZE, 
                "num_epochs_train" : 50}

# experiments = [
#     {
#         'name' : 'glove_emb_cfg1_no_num',
#         'glove_config' : glove_config1,
#         'disc' : None
#     },
#     {
#         'name' : 'glove_emb_cfg2_no_num',
#         'glove_config' : glove_config2,
#         'disc' : None
#     },
#     {
#         'name' : 'glove_emb_cfg3_no_num',
#         'glove_config' : glove_config3,
#         'disc' : None
#     },
#     {
#         'name' : 'glove_emb_cfg1_ST20',
#         'glove_config' : glove_config1,
#         'disc' : disc_st20
#     },
#     {
#         'name' : 'glove_emb_cfg2_quant100',
#         'glove_config' : glove_config2,
#         'disc' : disc_quant100
#     },
#     {
#         'name' : 'glove_emb_cfg3_quant100',
#         'glove_config' : glove_config3,
#         'disc' : disc_quant100
#     },
#     {
#         'name' : 'glove_emb_cfg2_deeptlf9',
#         'glove_config' : glove_config2,
#         'disc' : deeptlf_params9
#     },
# ]

glove_config2_8= {"alpha" : 0.75, 
                "x_max" : 15000, 
                "embedding_size" : 8, 
                "num_epochs_train" : 50}

glove_config2_100= {"alpha" : 0.75, 
                "x_max" : 15000, 
                "embedding_size" : 100, 
                "num_epochs_train" : 50}

glove_config2_100= {"alpha" : 0.75, 
                "x_max" : 15000, 
                "embedding_size" : 100, 
                "num_epochs_train" : 50}

experiments = [
    {
        'name' : 'glove_emb100_cfg2_deeptlf9',
        'glove_config' : glove_config2_100,
        'disc' : copy.deepcopy(deeptlf_params9)
    },
    {
        'name' : 'glove_emb100_cfg2_quant100',
        'glove_config' : glove_config2_100,
        'disc' : copy.deepcopy(disc_quant100)
    },
]

# %%
for exp in experiments:
    print(exp['name'])
    data = copy.deepcopy(source_data)
    disc = exp['disc']
    if disc is not None:
        if "ST" not in exp['name']:
            disc.fit(data)
            data = disc.transform(data, to_embeds=False)
        else:
            disc.fit(data.sample(int(1e+5), random_state=42).merge(targets, on=df_params['id_col'], how='left'))
            data = disc.transform(data, to_embeds=False)
        print(f"{exp['name']}: DATA DISCRETIZED")
        
        embedded_feats = df_params['numeric_cols'] + df_params['cat_cols'] + [df_params["date_col"]]
    else:
        embedded_feats = df_params['cat_cols'] + [df_params["date_col"]]
        
    print(embedded_feats)
    glove_embedding = GloveEmbedding(
            feature_names=embedded_feats,
            calculate_cooccur=True,
            embedding_folder=f'../glove_embeddings/{exp["name"]}',
            glove_params=exp['glove_config']
        )
    glove_embedding.fit(data)
    print(f"{exp['name']}: GLOVE EMB CALCULATED")
# Out:
# glove_emb100_cfg2_deeptlf9
# Counter({'small_group': 153, 'amount_rur': 62})
# glove_emb100_cfg2_deeptlf9: DATA DISCRETIZED
# ['amount_rur', 'small_group', 'trans_date']
# train started
#   2%|█▋                                                                                 | 1/50 [00:05<04:07,  5.04s/it]
# Epoch 0: loss = 23220.89856479372
#   4%|███▎                                                                               | 2/50 [00:09<03:54,  4.89s/it]
# Epoch 1: loss = 10183.293837865573
#   6%|████▉                                                                              | 3/50 [00:14<03:47,  4.85s/it]
# Epoch 2: loss = 6523.9176062426395
#   8%|██████▋                                                                            | 4/50 [00:19<03:41,  4.81s/it]
# Epoch 3: loss = 4585.108420480379
#  10%|████████▎                                                                          | 5/50 [00:24<03:36,  4.81s/it]
# Epoch 4: loss = 3452.036116423872
#  12%|█████████▉                                                                         | 6/50 [00:28<03:31,  4.81s/it]
# Epoch 5: loss = 2720.05925834801
#  14%|███████████▌                                                                       | 7/50 [00:33<03:27,  4.82s/it]
# Epoch 6: loss = 2213.8027064500375
#  16%|█████████████▎                                                                     | 8/50 [00:38<03:22,  4.81s/it]
# Epoch 7: loss = 1844.5983751961894
#  18%|██████████████▉                                                                    | 9/50 [00:43<03:17,  4.82s/it]
# Epoch 8: loss = 1565.774870194565
#  20%|████████████████▍                                                                 | 10/50 [00:48<03:12,  4.81s/it]
# Epoch 9: loss = 1347.5004610415187
#  22%|██████████████████                                                                | 11/50 [00:53<03:07,  4.81s/it]
# Epoch 10: loss = 1173.6789197191013
#  24%|███████████████████▋                                                              | 12/50 [00:57<03:02,  4.80s/it]
# Epoch 11: loss = 1031.676150404898
#  26%|█████████████████████▎                                                            | 13/50 [01:02<02:57,  4.81s/it]
# Epoch 12: loss = 914.4336197080781
#  28%|██████████████████████▉                                                           | 14/50 [01:07<02:55,  4.86s/it]
# Epoch 13: loss = 816.1405247086683
#  30%|████████████████████████▌                                                         | 15/50 [01:12<02:49,  4.84s/it]
# Epoch 14: loss = 732.8408764573363
#  32%|██████████████████████████▏                                                       | 16/50 [01:17<02:43,  4.82s/it]
# Epoch 15: loss = 661.5303341195589
#  34%|███████████████████████████▉                                                      | 17/50 [01:22<02:39,  4.83s/it]
# Epoch 16: loss = 600.1311509246099
#  36%|█████████████████████████████▌                                                    | 18/50 [01:26<02:33,  4.81s/it]
# Epoch 17: loss = 546.6585896397088
#  38%|███████████████████████████████▏                                                  | 19/50 [01:31<02:29,  4.81s/it]
# Epoch 18: loss = 499.96560004178735
#  40%|████████████████████████████████▊                                                 | 20/50 [01:36<02:23,  4.79s/it]
# Epoch 19: loss = 458.9128570706642
#  42%|██████████████████████████████████▍                                               | 21/50 [01:41<02:19,  4.80s/it]
# Epoch 20: loss = 422.6152069001859
#  44%|████████████████████████████████████                                              | 22/50 [01:45<02:13,  4.78s/it]
# Epoch 21: loss = 390.38836842388986
#  46%|█████████████████████████████████████▋                                            | 23/50 [01:50<02:09,  4.78s/it]
# Epoch 22: loss = 361.68979971292663
#  48%|███████████████████████████████████████▎                                          | 24/50 [01:55<02:04,  4.79s/it]
# Epoch 23: loss = 335.86625249614633
#  50%|█████████████████████████████████████████                                         | 25/50 [02:00<01:59,  4.78s/it]
# Epoch 24: loss = 312.72250924021995
#  52%|██████████████████████████████████████████▋                                       | 26/50 [02:05<01:55,  4.80s/it]
# Epoch 25: loss = 291.82344976204
#  54%|████████████████████████████████████████████▎                                     | 27/50 [02:09<01:50,  4.79s/it]
# Epoch 26: loss = 272.939236892831
#  56%|█████████████████████████████████████████████▉                                    | 28/50 [02:14<01:45,  4.80s/it]
# Epoch 27: loss = 255.94908873886015
#  58%|███████████████████████████████████████████████▌                                  | 29/50 [02:19<01:42,  4.88s/it]
# Epoch 28: loss = 240.27901612164138
#  60%|█████████████████████████████████████████████████▏                                | 30/50 [02:24<01:37,  4.86s/it]
# Epoch 29: loss = 225.96753295763332
#  62%|██████████████████████████████████████████████████▊                               | 31/50 [02:29<01:33,  4.90s/it]
# Epoch 30: loss = 212.9223904286363
#  64%|████████████████████████████████████████████████████▍                             | 32/50 [02:34<01:28,  4.92s/it]
# Epoch 31: loss = 201.05544200671977
#  66%|██████████████████████████████████████████████████████                            | 33/50 [02:39<01:23,  4.91s/it]
# Epoch 32: loss = 190.00948322643973
#  68%|███████████████████████████████████████████████████████▊                          | 34/50 [02:44<01:19,  4.95s/it]
# Epoch 33: loss = 179.96446880419109
#  70%|█████████████████████████████████████████████████████████▍                        | 35/50 [02:49<01:13,  4.92s/it]
# Epoch 34: loss = 170.64051417305404
#  72%|███████████████████████████████████████████████████████████                       | 36/50 [02:54<01:08,  4.90s/it]
# Epoch 35: loss = 161.96162213640036
#  74%|████████████████████████████████████████████████████████████▋                     | 37/50 [02:58<01:03,  4.86s/it]
# Epoch 36: loss = 153.9733225834436
#  76%|██████████████████████████████████████████████████████████████▎                   | 38/50 [03:03<00:58,  4.88s/it]
# Epoch 37: loss = 146.65747199467054
#  78%|███████████████████████████████████████████████████████████████▉                  | 39/50 [03:08<00:53,  4.88s/it]
# Epoch 38: loss = 139.69825734443353
#  80%|█████████████████████████████████████████████████████████████████▌                | 40/50 [03:13<00:49,  4.92s/it]
# Epoch 39: loss = 133.3110741113544
#  82%|███████████████████████████████████████████████████████████████████▏              | 41/50 [03:18<00:44,  4.95s/it]
# Epoch 40: loss = 127.4060947630491
#  84%|████████████████████████████████████████████████████████████████████▉             | 42/50 [03:23<00:39,  4.94s/it]
# Epoch 41: loss = 121.77651097223679
#  86%|██████████████████████████████████████████████████████████████████████▌           | 43/50 [03:28<00:34,  4.90s/it]
# Epoch 42: loss = 116.58716339496176
#  88%|████████████████████████████████████████████████████████████████████████▏         | 44/50 [03:33<00:29,  4.91s/it]
# Epoch 43: loss = 111.70872262642261
#  90%|█████████████████████████████████████████████████████████████████████████▊        | 45/50 [03:38<00:24,  4.96s/it]
# Epoch 44: loss = 107.15353835576886
#  92%|███████████████████████████████████████████████████████████████████████████▍      | 46/50 [03:43<00:19,  4.92s/it]
# Epoch 45: loss = 102.87625893975817
#  94%|█████████████████████████████████████████████████████████████████████████████     | 47/50 [03:48<00:14,  4.88s/it]
# Epoch 46: loss = 98.89028446823322
#  96%|██████████████████████████████████████████████████████████████████████████████▋   | 48/50 [03:52<00:09,  4.86s/it]
# Epoch 47: loss = 95.08842407508958
#  98%|████████████████████████████████████████████████████████████████████████████████▎ | 49/50 [03:57<00:04,  4.85s/it]
# Epoch 48: loss = 91.53150283869431
# 100%|██████████████████████████████████████████████████████████████████████████████████| 50/50 [04:02<00:00,  4.85s/it]
# Epoch 49: loss = 88.18002719497368
# glove_emb100_cfg2_deeptlf9: GLOVE EMB CALCULATED
# glove_emb100_cfg2_quant100
# glove_emb100_cfg2_quant100: DATA DISCRETIZED
# ['amount_rur', 'small_group', 'trans_date']
# train started
#   2%|█▋                                                                                 | 1/50 [00:07<05:47,  7.09s/it]
# Epoch 0: loss = 26205.37468140735
#   4%|███▎                                                                               | 2/50 [00:14<05:35,  6.99s/it]
# Epoch 1: loss = 12254.220766626859
#   6%|████▉                                                                              | 3/50 [00:20<05:26,  6.95s/it]
# Epoch 2: loss = 8138.182656392525
#   8%|██████▋                                                                            | 4/50 [00:27<05:19,  6.95s/it]
# Epoch 3: loss = 5933.838105001424
#  10%|████████▎                                                                          | 5/50 [00:34<05:12,  6.95s/it]
# Epoch 4: loss = 4591.542683162226
#  12%|█████████▉                                                                         | 6/50 [00:42<05:13,  7.12s/it]
# Epoch 5: loss = 3698.6753877845035
#  14%|███████████▌                                                                       | 7/50 [00:50<05:15,  7.34s/it]
# Epoch 6: loss = 3064.782804684664
#  16%|█████████████▎                                                                     | 8/50 [00:57<05:13,  7.46s/it]
# Epoch 7: loss = 2591.8264739187484
#  18%|██████████████▉                                                                    | 9/50 [01:05<05:10,  7.56s/it]
# Epoch 8: loss = 2226.5778197585287
#  20%|████████████████▍                                                                 | 10/50 [01:13<05:04,  7.61s/it]
# Epoch 9: loss = 1935.7494665021436
#  22%|██████████████████                                                                | 11/50 [01:21<04:58,  7.65s/it]
# Epoch 10: loss = 1699.9046491204863
#  24%|███████████████████▋                                                              | 12/50 [01:28<04:52,  7.71s/it]
# Epoch 11: loss = 1505.8660220366644
#  26%|█████████████████████▎                                                            | 13/50 [01:36<04:45,  7.71s/it]
# Epoch 12: loss = 1342.4014479858242
#  28%|██████████████████████▉                                                           | 14/50 [01:44<04:37,  7.70s/it]
# Epoch 13: loss = 1204.782917396413
#  30%|████████████████████████▌                                                         | 15/50 [01:52<04:29,  7.71s/it]
# Epoch 14: loss = 1086.6092904242926
#  32%|██████████████████████████▏                                                       | 16/50 [01:59<04:22,  7.72s/it]
# Epoch 15: loss = 985.0412252051868
#  34%|███████████████████████████▉                                                      | 17/50 [02:07<04:14,  7.72s/it]
# Epoch 16: loss = 896.902441776756
#  36%|█████████████████████████████▌                                                    | 18/50 [02:15<04:06,  7.71s/it]
# Epoch 17: loss = 819.4195034787838
#  38%|███████████████████████████████▏                                                  | 19/50 [02:22<03:59,  7.72s/it]
# Epoch 18: loss = 751.5996092514777
#  40%|████████████████████████████████▊                                                 | 20/50 [02:30<03:52,  7.74s/it]
# Epoch 19: loss = 691.6726218206985
#  42%|██████████████████████████████████▍                                               | 21/50 [02:38<03:44,  7.73s/it]
# Epoch 20: loss = 638.2849503429397
#  44%|████████████████████████████████████                                              | 22/50 [02:46<03:35,  7.71s/it]
# Epoch 21: loss = 590.6996630419425
#  46%|█████████████████████████████████████▋                                            | 23/50 [02:53<03:28,  7.72s/it]
# Epoch 22: loss = 548.1235001537489
#  48%|███████████████████████████████████████▎                                          | 24/50 [03:01<03:20,  7.72s/it]
# Epoch 23: loss = 509.8474035712781
#  50%|█████████████████████████████████████████                                         | 25/50 [03:09<03:12,  7.71s/it]
# Epoch 24: loss = 475.4511025695373
#  52%|██████████████████████████████████████████▋                                       | 26/50 [03:16<03:05,  7.72s/it]
# Epoch 25: loss = 444.0465935477198
#  54%|████████████████████████████████████████████▎                                     | 27/50 [03:24<02:57,  7.74s/it]
# Epoch 26: loss = 415.69433453251514
#  56%|█████████████████████████████████████████████▉                                    | 28/50 [03:32<02:50,  7.75s/it]
# Epoch 27: loss = 389.90880548870194
#  58%|███████████████████████████████████████████████▌                                  | 29/50 [03:40<02:42,  7.75s/it]
# Epoch 28: loss = 366.38295700992774
#  60%|█████████████████████████████████████████████████▏                                | 30/50 [03:47<02:34,  7.73s/it]
# Epoch 29: loss = 344.883615310641
#  62%|██████████████████████████████████████████████████▊                               | 31/50 [03:55<02:28,  7.80s/it]
# Epoch 30: loss = 325.4431123671649
#  64%|████████████████████████████████████████████████████▍                             | 32/50 [04:03<02:20,  7.78s/it]
# Epoch 31: loss = 307.27981721108944
#  66%|██████████████████████████████████████████████████████                            | 33/50 [04:11<02:12,  7.78s/it]
# Epoch 32: loss = 290.3023258565766
#  68%|███████████████████████████████████████████████████████▊                          | 34/50 [04:19<02:04,  7.75s/it]
# Epoch 33: loss = 274.8923060275332
#  70%|█████████████████████████████████████████████████████████▍                        | 35/50 [04:26<01:56,  7.77s/it]
# Epoch 34: loss = 260.8746527856043
#  72%|███████████████████████████████████████████████████████████                       | 36/50 [04:34<01:49,  7.79s/it]
# Epoch 35: loss = 247.5139398714766
#  74%|████████████████████████████████████████████████████████████▋                     | 37/50 [04:42<01:41,  7.78s/it]
# Epoch 36: loss = 235.29616282669238
#  76%|██████████████████████████████████████████████████████████████▎                   | 38/50 [04:50<01:35,  7.93s/it]
# Epoch 37: loss = 223.96049694781416
#  78%|███████████████████████████████████████████████████████████████▉                  | 39/50 [04:58<01:26,  7.87s/it]
# Epoch 38: loss = 213.420119216619
#  80%|█████████████████████████████████████████████████████████████████▌                | 40/50 [05:06<01:18,  7.85s/it]
# Epoch 39: loss = 203.59592178553936
#  82%|███████████████████████████████████████████████████████████████████▏              | 41/50 [05:14<01:10,  7.81s/it]
# Epoch 40: loss = 194.45006968553687
#  84%|████████████████████████████████████████████████████████████████████▉             | 42/50 [05:21<01:01,  7.72s/it]
# Epoch 41: loss = 185.92198801336068
#  86%|██████████████████████████████████████████████████████████████████████▌           | 43/50 [05:28<00:53,  7.62s/it]
# Epoch 42: loss = 177.91044583432682
#  88%|████████████████████████████████████████████████████████████████████████▏         | 44/50 [05:36<00:45,  7.55s/it]
# Epoch 43: loss = 170.3725042444521
#  90%|█████████████████████████████████████████████████████████████████████████▊        | 45/50 [05:43<00:37,  7.50s/it]
# Epoch 44: loss = 163.35978213152583
#  92%|███████████████████████████████████████████████████████████████████████████▍      | 46/50 [05:51<00:29,  7.44s/it]
# Epoch 45: loss = 156.75453020790638
#  94%|█████████████████████████████████████████████████████████████████████████████     | 47/50 [05:58<00:22,  7.42s/it]
# Epoch 46: loss = 150.58156812347517
#  96%|██████████████████████████████████████████████████████████████████████████████▋   | 48/50 [06:05<00:14,  7.41s/it]
# Epoch 47: loss = 144.74240705227317
#  98%|████████████████████████████████████████████████████████████████████████████████▎ | 49/50 [06:13<00:07,  7.43s/it]
# Epoch 48: loss = 139.24419825383458
# 100%|██████████████████████████████████████████████████████████████████████████████████| 50/50 [06:20<00:00,  7.61s/it]
# Epoch 49: loss = 134.0477485785535
# glove_emb100_cfg2_quant100: GLOVE EMB CALCULATED

# %%
glove_embedding.load()

# %%
data = glove_embedding.tokenize_data(data)

# %%
EMBED_SIZE = 16
disc_quant100 = KDiscretizer(
    f_names = ['amount_rur'],
    k_bins = 100,
    d_type = 'quantile'
)

disc_uni100 = KDiscretizer(
    f_names = ['amount_rur'],
    k_bins = 100,
    d_type = 'uniform'
)

disc_kmeans100 = KDiscretizer(
    f_names = ['amount_rur'],
    k_bins = 100,
    d_type = 'kmeans'
)

disc_st100 = SingleTreeDiscretizer(
    f_names = ['amount_rur'], 
    target_name = 'bins', 
    target_type = 'classification', 
    k_bins = [100],
)

disc_quant30 = KDiscretizer(
    f_names = ['amount_rur'],
    k_bins = 30,
    d_type = 'quantile',
    emb_sz = EMBED_SIZE
)

disc_uni30 = KDiscretizer(
    f_names = ['amount_rur'],
    k_bins = 30,
    d_type = 'uniform',
    emb_sz = EMBED_SIZE
)

disc_kmeans30 = KDiscretizer(
    f_names = ['amount_rur'],
    k_bins = 30,
    d_type = 'kmeans',
    emb_sz = EMBED_SIZE
)

disc_st30 = SingleTreeDiscretizer(
    f_names = ['amount_rur'], 
    target_name = 'bins', 
    target_type = 'classification', 
    k_bins = [30],
    emb_sz = EMBED_SIZE
)

# %%
experiments = [
    {'name' : 'quant_num_emb_dist_common_emb_cat', 
     'agg_type' : 'cat', 
     'disc' : disc_quant30,
     'nemb' : True
    },
    {'name' : 'quant_num_emb_dist_common_emb_sum', 
     'agg_type' : 'sum', 
     'disc' : disc_quant30,
     'nemb' : True
    },
    {'name' : 'quant_num_emb_dist_common_emb_mean', 
     'agg_type' : 'mean', 
     'disc' : disc_quant30,
     'nemb' : True
    },
    {'name' : 'uni_num_emb_dist_common_emb_cat', 
     'agg_type' : 'cat', 
     'disc' : disc_uni30,
     'nemb' : True
    },
    {'name' : 'uni_num_emb_dist_common_emb_sum', 
     'agg_type' : 'sum', 
     'disc' : disc_uni30,
     'nemb' : True
    },
    {'name' : 'uni_num_emb_dist_common_emb_mean', 
     'agg_type' : 'mean', 
     'disc' : disc_uni30,
     'nemb' : True
    },
    {'name' : 'kmeans_num_emb_dist_common_emb_cat', 
     'agg_type' : 'cat', 
     'disc' : disc_kmeans30,
     'nemb' : True
    },
    {'name' : 'kmeans_num_emb_dist_common_emb_sum', 
     'agg_type' : 'sum', 
     'disc' : disc_kmeans30,
     'nemb' : True
    },
    {'name' : 'kmeans_num_emb_dist_common_emb_mean', 
     'agg_type' : 'mean', 
     'disc' : disc_kmeans30,
     'nemb' : True
    },
    {'name' : 'st_num_emb_dist_common_emb_cat', 
     'agg_type' : 'cat', 
     'disc' : disc_st30,
     'nemb' : True
    },
    {'name' : 'st_num_emb_dist_common_emb_sum', 
     'agg_type' : 'sum', 
     'disc' : disc_st30,
     'nemb' : True
    },
    {'name' : 'st_num_emb_dist_common_emb_mean', 
     'agg_type' : 'mean', 
     'disc' : disc_st30,
     'nemb' : True
    },
    {'name' : 'st_100_dist_common_emb_cat', 
     'agg_type' : 'cat', 
     'disc' : disc_st100,
     'nemb' : False
    },
    {'name' : 'st_100_dist_common_emb_sum', 
     'agg_type' : 'sum', 
     'disc' : disc_st100,
     'nemb' : False
    },
    {'name' : 'st_100_dist_common_emb_mean', 
     'agg_type' : 'mean', 
     'disc' : disc_st100,
     'nemb' : False
    },
    {'name' : 'quant_100_dist_common_emb_cat', 
     'agg_type' : 'cat', 
     'disc' : disc_quant100,
     'nemb' : False
    },
    {'name' : 'quant_100_dist_common_emb_sum', 
     'agg_type' : 'sum', 
     'disc' : disc_quant100,
     'nemb' : False
    },
    {'name' : 'quant_100_dist_common_emb_mean', 
     'agg_type' : 'mean', 
     'disc' : disc_quant100,
     'nemb' : False
    },
    {'name' : 'uni_100_dist_common_emb_cat', 
     'agg_type' : 'cat', 
     'disc' : disc_uni100,
     'nemb' : False
    },
    {'name' : 'uni_100_dist_common_emb_sum', 
     'agg_type' : 'sum', 
     'disc' : disc_uni100,
     'nemb' : False
    },
    {'name' : 'uni_100_dist_common_emb_mean', 
     'agg_type' : 'mean', 
     'disc' : disc_uni100,
     'nemb' : False
    },
    {'name' : 'kmeans_100_dist_common_emb_cat', 
     'agg_type' : 'cat', 
     'disc' : disc_kmeans100,
     'nemb' : False
    },
    {'name' : 'kmeans_100_dist_common_emb_sum', 
     'agg_type' : 'sum', 
     'disc' : disc_kmeans100,
     'nemb' : False
    },
    {'name' : 'kmeans_100_dist_common_emb_mean', 
     'agg_type' : 'mean', 
     'disc' : disc_kmeans100,
     'nemb' : False
    },
]

# %%
#Deeptfl only disc
EMBED_SIZE = 16
df_params = {'numeric_cols': ['amount_rur'],
     'cat_cols': ['small_group'],
     'date_col': 'trans_date',
     'cat_unique': [202, 730],
     'id_col': 'client_id'}

deeptlf_params3 = DeepTLFDisc({"n_est" : 3,
                  "min_freq" : 2,
                  "features" : df_params['numeric_cols'] + df_params['cat_cols'],
                  "features_to_split" : df_params['numeric_cols']
                  })
deeptlf_params6 = DeepTLFDisc({"n_est" : 6,
                  "min_freq" : 2,
                  "features" : df_params['numeric_cols'] + df_params['cat_cols'],
                  "features_to_split" : df_params['numeric_cols'],
                  })
deeptlf_params9 = DeepTLFDisc({"n_est" : 9,
                  "min_freq" : 2,
                  "features" : df_params['numeric_cols'] + df_params['cat_cols'],
                  "features_to_split" : df_params['numeric_cols'],
                  })

deeptlf_params3_ne = DeepTLFDisc({"n_est" : 3,
                  "min_freq" : 2,
                  "features" : df_params['numeric_cols'] + df_params['cat_cols'],
                  "features_to_split" : df_params['numeric_cols'],
                  "emb_size" : EMBED_SIZE})
deeptlf_params6_ne = DeepTLFDisc({"n_est" : 6,
                  "min_freq" : 2,
                  "features" : df_params['numeric_cols'] + df_params['cat_cols'],
                  "features_to_split" : df_params['numeric_cols'],
                  "emb_size" : EMBED_SIZE})
deeptlf_params9_ne = DeepTLFDisc({"n_est" : 9,
                  "min_freq" : 2,
                  "features" : df_params['numeric_cols'] + df_params['cat_cols'],
                  "features_to_split" : df_params['numeric_cols'],
                  "emb_size" : EMBED_SIZE})

experiments = [
    {'name' : 'deeptlf3_disc_common_emb_cat',
     'agg_type' : 'cat',
     'disc' : deeptlf_params3,
     'nemb' : False
    },
    {'name' : 'deeptlf6_disc_common_emb_sum',
     'agg_type' : 'sum',
     'disc' : deeptlf_params6,
     'nemb' : False
    },
    {'name' : 'deeptlf9_disc_common_emb_mean',
     'agg_type' : 'mean',
     'disc' : deeptlf_params9,
     'nemb' : False
    },
    {'name' : 'deeptlf3_num_emb_disc_common_emb_cat',
     'agg_type' : 'cat',
     'disc' : deeptlf_params3_ne,
     'nemb' : True
    },
    {'name' : 'deeptlf6_num_emb_disc_common_emb_sum',
     'agg_type' : 'sum',
     'disc' : deeptlf_params6_ne,
     'nemb' : True
    },
    {'name' : 'deeptlf9_num_emb_disc_common_emb_mean',
     'agg_type' : 'mean',
     'disc' : deeptlf_params9_ne,
     'nemb' : True
    },
]

# %%
EMBED_SIZE = 16
TARGET_NAME = 'bins'
# df_params = {'numeric_cols': ['amount'],
#              'cat_cols': ['mcc_code', 'tr_type'],
#              'cat_unique': [184, 77, 457],
#              'date_col': 'tr_datetime',
#              'id_col': 'client_id'
#     }

df_params = {'numeric_cols': ['amount_rur'],
     'cat_cols': ['small_group'],
     'date_col': 'trans_date',
     'cat_unique': [202, 730],
     'id_col': 'client_id'
}

disc_quant100 = KDiscretizer(
    f_names = df_params['numeric_cols'],
    k_bins = 100,
    d_type = 'quantile'
)

disc_st20 = SingleTreeDiscretizer(
    f_names = df_params['numeric_cols'], 
    target_name = TARGET_NAME, 
    target_type = 'classification', 
    k_bins = [20],
)

disc_st30 = SingleTreeDiscretizer(
    f_names = df_params['numeric_cols'], 
    target_name = TARGET_NAME, 
    target_type = 'classification', 
    k_bins = [30],
    emb_sz = EMBED_SIZE
)


deeptlf_params9 = DeepTLFDisc({"n_est" : 9,
                  "min_freq" : 2,
                  "features" : df_params['numeric_cols'] + df_params['cat_cols'],
                  "features_to_split" : df_params['numeric_cols'],
                  })

disc_quant30 = KDiscretizer(
    f_names = ['amount_rur'],
    k_bins = 30,
    d_type = 'quantile',
    emb_sz = EMBED_SIZE
)


experiments = [
     {'name' : 'quant_100_dist_common_emb_myparams1_cat', 
     'agg_type' : 'cat', 
     'disc' : copy.deepcopy(disc_quant100),
     'nemb' : False
    },
     {'name' : 'quant_num_emb_dist_common_emb_cat', 
     'agg_type' : 'cat', 
     'disc' : copy.deepcopy(disc_quant30),
     'nemb' : True
    },
     {'name' : 'st_num_emb_dist_common_emb_sum', 
     'agg_type' : 'sum', 
     'disc' : copy.deepcopy(disc_st30),
     'nemb' : True
    },
    {'name' : 'st_num_emb_dist_common_emb_mean', 
     'agg_type' : 'mean', 
     'disc' : copy.deepcopy(disc_st30),
     'nemb' : True
    },
    {'name' : 'quant_100_dist_common_emb_sum', 
     'agg_type' : 'sum', 
     'disc' : copy.deepcopy(disc_quant100),
     'nemb' : False
    },
    {'name' : 'quant_100_dist_common_emb_mean', 
     'agg_type' : 'mean', 
     'disc' : copy.deepcopy(disc_quant100),
     'nemb' : False
    },
    {'name' : 'st_20_dist_common_emb_cat', 
     'agg_type' : 'cat', 
     'disc' : copy.deepcopy(disc_st20),
     'nemb' : False
    },
    {'name' : 'st_20_dist_common_emb_sum', 
     'agg_type' : 'sum', 
     'disc' : copy.deepcopy(disc_st20),
     'nemb' : False
    },
    {'name' : 'st_20_dist_common_emb_mean', 
     'agg_type' : 'mean', 
     'disc' : copy.deepcopy(disc_st20),
     'nemb' : False
    },
     {'name' : 'deeptlf9_disc_common_emb_cat',
     'agg_type' : 'cat',
     'disc' : copy.deepcopy(deeptlf_params9),
     'nemb' : False
    },
    {'name' : 'deeptlf9_disc_common_emb_sum',
     'agg_type' : 'sum',
     'disc' : copy.deepcopy(deeptlf_params9),
     'nemb' : False
    },
    {'name' : 'deeptlf9_disc_common_emb_mean',
     'agg_type' : 'mean',
     'disc' : copy.deepcopy(deeptlf_params9),
     'nemb' : False
    }
]

# %% [markdown]
# ### Experiments with sole numeric features discretization and common embeds

# %%
EMBED_SIZE = 16
HIDDEN_SIZE = 256

def get_basic_model_encoder(df_params):
    embeddings=dict()
    for i, f in enumerate(df_params["cat_cols"] + [df_params["date_col"]]):
        embeddings[f] = {'in' : df_params["cat_unique"][i], 'out' : EMBED_SIZE}
    
    trx_encoder_params = dict(
        embeddings_noise=0.003,
        numeric_values=dict([(fe, 'identity') for fe in df_params['numeric_cols']]),
        embeddings=embeddings
    )
    
    seq_encoder = RnnSeqEncoder(
        trx_encoder=TrxEncoder(**trx_encoder_params),
        hidden_size=256,
        type='gru',
    )
    
    return seq_encoder

def get_cat_encoder(df_params, agg_type, num_emb_flag=False):
    embeddings=dict()
    for i, f in enumerate(df_params["cat_cols"] + [df_params["date_col"]]):
        embeddings[f] = {'in' : df_params["cat_unique"][i], 'out' : EMBED_SIZE}

    trx_encoder_params = dict(
        embeddings=embeddings,
        embeddings_noise=0.003,
        agg_type=agg_type,
        numeric_separate=num_emb_flag,
        numeric_features=df_params['numeric_cols']
    )
    
    seq_encoder = RnnSeqEncoder(
        trx_encoder=TrxEncoderCat(**trx_encoder_params),
        hidden_size=HIDDEN_SIZE,
        type='gru',
    )
    return seq_encoder

def get_trans_encoder(df_params, agg_type, algo, numeric_separate=False):
    embeddings=dict()

    trx_encoder_params = dict(
        feature_names=df_params['cat_cols'] + [df_params["date_col"]], 
        in_emb_sizes=df_params["cat_unique"],
        out_emb_size=EMBED_SIZE,
        agg_type=agg_type,
        numeric_separate=numeric_separate,
        numeric_features=df_params['numeric_cols']
    )
    
    seq_encoder = RnnSeqEncoder(
        trx_encoder=TrxEncoderTrans(**trx_encoder_params),
        hidden_size=HIDDEN_SIZE,
        type='gru',
    )
    return seq_encoder

def get_glove_encoder(df_params, exp, glove_embedding):
    seq_encoder = RnnSeqEncoder(
        trx_encoder=TrxEncoderGlove(glove_embedding, agg_type=exp['agg_type'], numeric_separate=exp['nsep']),
        hidden_size=256,
        type='gru',
    )
    return seq_encoder

# %%
disc_quant100 = KDiscretizer(
    f_names = ['amount_rur'],
    k_bins = 100,
    d_type = 'quantile'
)

deeptlf_params9 = DeepTLFDisc({"n_est" : 9,
                  "min_freq" : 2,
                  "features" : df_params['numeric_cols'] + df_params['cat_cols'],
                  "features_to_split" : df_params['numeric_cols'],
                  })

experiments = [
    {
     'name' : 'trx_tran_orig_no_disc',
     'algo' : 'orig',
     'agg_type' : None,
     'nsep' : False,
    },
    {
     'name' : 'trx_tran_orig_deeptlf9',
     'algo' : 'orig',
     'agg_type' : None,
     'nsep' : False,
     'disc' : copy.deepcopy(deeptlf_params9),
     'nemb' : False
    },
    {
     'name' : 'trx_tran_classic_deeptlf9_cat',
     'algo' : 'classic',
     'agg_type' : 'cat',
     'nsep' : False,
     'disc' : copy.deepcopy(deeptlf_params9),
     'nemb' : False
    },
    {
     'name' : 'trx_tran_classic_quant100_sum',
     'algo' : 'classic',
     'agg_type' : 'sum',
     'nsep' : False,
     'disc' : copy.deepcopy(disc_quant100),
     'nemb' : False
    },
    {
     'name' : 'trx_tran_orig_quant100',
     'algo' : 'orig',
     'agg_type' : None,
     'nsep' : False,
     'disc' : copy.deepcopy(disc_quant100),
     'nemb' : False
    },
    {
     'name' : 'trx_tran_classic_quant100_cat',
     'algo' : 'classic',
     'agg_type' : 'cat',
     'nsep' : False,
     'disc' : copy.deepcopy(disc_quant100),
     'nemb' : False
    },
      {
     'name' : 'trx_tran_classic_deeptlf9_sum',
     'algo' : 'classic',
     'agg_type' : 'sum',
     'nsep' : False,
     'disc' : copy.deepcopy(deeptlf_params9),
     'nemb' : False
    },
    #  {
    #  'name' : 'trx_tran_classic_deeptlf9_mean',
    #  'algo' : 'classic',
    #  'agg_type' : 'mean',
    #  'nsep' : False,
    #  'disc' : copy.deepcopy(deeptlf_params9),
    #  'nemb' : False
    # },
    # {
    #  'name' : 'trx_tran_classic_quant100_mean',
    #  'algo' : 'classic',
    #  'agg_type' : 'mean',
    #  'nsep' : False,
    #  'disc' : copy.deepcopy(disc_quant100),
    #  'nemb' : False
    # },
    {
     'name' : 'trx_tran_classic_no_disc_cat',
     'algo' : 'classic',
     'agg_type' : 'cat',
     'nsep' : True,
    }
]

# %%
experiments_glove = []
for e in experiments:
    for agg_t in ['cat']:
        if agg_t != 'cat' and e['disc'] is None:
            continue
        experiments_glove.append(copy.deepcopy(e))
        experiments_glove[-1]['agg_type'] = agg_t
        experiments_glove[-1]['nsep'] = (experiments_glove[-1]['disc'] is None)
        experiments_glove[-1]['name'] += f'_{agg_t}'

# %%
experiments_glove
# Out:
# [{'name': 'glove_emb100_cfg2_deeptlf9_cat',
#   'glove_config': {'alpha': 0.75,
#    'x_max': 15000,
#    'embedding_size': 100,
#    'num_epochs_train': 50},
#   'disc': <ptls.preprocessing.deeptlf.deeptlf_discretizer.DeepTLFDisc at 0x2027f828e20>,
#   'agg_type': 'cat',
#   'nsep': False},
#  {'name': 'glove_emb100_cfg2_deeptlf9_sum',
#   'glove_config': {'alpha': 0.75,
#    'x_max': 15000,
#    'embedding_size': 100,
#    'num_epochs_train': 50},
#   'disc': <ptls.preprocessing.deeptlf.deeptlf_discretizer.DeepTLFDisc at 0x2027f828850>,
#   'agg_type': 'sum',
#   'nsep': False},
#  {'name': 'glove_emb100_cfg2_deeptlf9_mean',
#   'glove_config': {'alpha': 0.75,
#    'x_max': 15000,
#    'embedding_size': 100,
#    'num_epochs_train': 50},
#   'disc': <ptls.preprocessing.deeptlf.deeptlf_discretizer.DeepTLFDisc at 0x2027f82b1f0>,
#   'agg_type': 'mean',
#   'nsep': False},
#  {'name': 'glove_emb100_cfg2_quant100_cat',
#   'glove_config': {'alpha': 0.75,
#    'x_max': 15000,
#    'embedding_size': 100,
#    'num_epochs_train': 50},
#   'disc': <ptls.preprocessing.baseline_discretizer.k_discretizer.KDiscretizer at 0x2027f82bb50>,
#   'agg_type': 'cat',
#   'nsep': False},
#  {'name': 'glove_emb100_cfg2_quant100_sum',
#   'glove_config': {'alpha': 0.75,
#    'x_max': 15000,
#    'embedding_size': 100,
#    'num_epochs_train': 50},
#   'disc': <ptls.preprocessing.baseline_discretizer.k_discretizer.KDiscretizer at 0x20280cd0070>,
#   'agg_type': 'sum',
#   'nsep': False},
#  {'name': 'glove_emb100_cfg2_quant100_mean',
#   'glove_config': {'alpha': 0.75,
#    'x_max': 15000,
#    'embedding_size': 100,
#    'num_epochs_train': 50},
#   'disc': <ptls.preprocessing.baseline_discretizer.k_discretizer.KDiscretizer at 0x20280cd27a0>,
#   'agg_type': 'mean',
#   'nsep': False}]

# %%
experiments = [
    {
        'name' : 'basic_model_emb_16',
        'nsep' : True
    }
]

# %%
experiments_glove = experiments_glove[2:] + experiments

# %%
for exp in experiments[:1]:
    df_params = {'numeric_cols': ['amount_rur'],
     'cat_cols': ['small_group'],
     'date_col': 'trans_date',
     'cat_unique': [202, 730],
     'id_col': 'client_id'}
    data = copy.deepcopy(source_data)
    if 'disc' in exp:
        disc = exp['disc']
        if exp['name'][:2] != "st" and ('ST' not in exp['name']) and (disc is not None):
            disc.fit(data)
            data = disc.transform(data, to_embeds=exp['nemb'] if 'nemb' in exp else False)
        elif (disc is not None):
            disc.fit(data.sample(int(1e+5), random_state=42).merge(targets, on=df_params['id_col'], how='left'))
            data = disc.transform(data, to_embeds=exp['nemb'] if 'nemb' in exp else False)
        print(f"{exp['name']}: DATA DISCRETIZED")

    if 'nemb' in exp and not exp['nemb']:
        df_params['cat_cols'] =  df_params['numeric_cols'] + df_params['cat_cols']
        df_params["cat_unique"] = (exp['disc'].k_bins if (type(exp['disc'].k_bins) is list) else [exp['disc'].k_bins] * len(df_params['numeric_cols'])) + df_params["cat_unique"]
        df_params['numeric_cols'] = []
    
    if 'glove_config' in exp:
        if not exp['nsep']:
            embedded_feats = df_params['numeric_cols'] + df_params['cat_cols'] + [df_params["date_col"]]
        else:
            embedded_feats = df_params['cat_cols'] + [df_params["date_col"]]
        folder_nm = f'../glove_embeddings/{exp["name"]}'[:-4] if exp['agg_type'] != 'mean' else f'../glove_embeddings/{exp["name"]}'[:-5]
        glove_embedding = GloveEmbedding(
            feature_names=embedded_feats,
            calculate_cooccur=False,
            embedding_folder=folder_nm,
            glove_params=exp['glove_config']
        )
        glove_embedding.load()
        data = glove_embedding.tokenize_data(data)

    preprocessor = PandasDataPreprocessor(
        col_id=df_params['id_col'],
        col_event_time=df_params['date_col'],
        event_time_transformation='none',
        category_transformation = 'none' if ('glove_config' in exp) else 'frequency',
        cols_category=df_params['cat_cols'],
        cols_numerical=df_params['numeric_cols'],
        return_records=True,
    )
#+ (df_params['numeric_cols'] if ('glove_config' in exp) else [])
#if ('nsep' in exp and exp['nsep']) else []    
    dataset = preprocessor.fit_transform(data)

    dataset = sorted(dataset, key=lambda x: x[df_params['id_col']])

    with open(f"../coles_prep_datasets/{exp['name']}_dataset.pkl", "wb") as fl:
        pickle.dump(dataset , fl)

    # with open(f"../coles_prep_datasets/{exp['name']}_dataset.pkl", "rb") as fl:
    #     dataset = pickle.load(fl)
    
    train, test = train_test_split(dataset, test_size=0.2, random_state=42)

    train, val = train_test_split(dataset, test_size=0.1, random_state=42)


    print(f"{exp['name']}: DATA PREPROCESSED AND SAVED")

    del dataset, data

    train_dl = PtlsDataModule(
        train_data = ColesDataset(
                MemoryMapDataset(
                    data=train,
                    i_filters=[
                        SeqLenFilter(min_seq_len=25),
                    ],
                ),
                splitter=SampleSlices(
                    split_count=5,
                    cnt_min=25,
                    cnt_max=200,
                ),
            ),
        train_num_workers=1,
        train_batch_size=256,
        valid_data = ColesDataset(
                MemoryMapDataset(
                    data=val,
                    i_filters=[
                        SeqLenFilter(min_seq_len=25),
                    ],
                ),
                splitter=SampleSlices(
                    split_count=5,
                    cnt_min=25,
                    cnt_max=200,
                ),
            ),
        valid_num_workers=1,
        valid_batch_size=256,
    )

    seq_encoder = get_cat_encoder(df_params, agg_type=exp['agg_type'], num_emb_flag=exp['nemb'])
    #seq_encoder = get_trans_encoder(df_params, agg_type=exp['agg_type'], algo=exp['algo'], numeric_separate=exp['nsep'])
    #seq_encoder = get_glove_encoder(df_params, exp, glove_embedding)
    #seq_encoder = get_basic_model_encoder(df_params)

    model = CoLESModule(
        seq_encoder=seq_encoder,
        optimizer_partial=partial(torch.optim.Adam, lr=0.001),
        lr_scheduler_partial=partial(torch.optim.lr_scheduler.StepLR, step_size=30, gamma=0.9),
    )

    early_stopping = EarlyStopping(f'valid/{model.metric_name}', mode='max', patience=2, min_delta=0.01)
    
    trainer = pl.Trainer(
        max_epochs=25,
        accelerator="gpu",
        callbacks = [early_stopping],
        enable_progress_bar=True,
        enable_model_summary=False,
        logger=False
    )

    print(f"{exp['name']}: TRAIN STARTS")

    trainer.fit(model, train_dl)
    print(trainer.logged_metrics)

    torch.save(seq_encoder.state_dict(), f"../models_coles/{exp['name']}_emb.pt")

    print(f"{exp['name']}: TRAIN ENDS, MODEL SAVED")

    del train, test
# Out:
# trx_tran_classic_no_disc_cat: DATA PREPROCESSED AND SAVED
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# C:\Users\peter\anaconda3\envs\cv\lib\site-packages\pytorch_lightning\callbacks\model_checkpoint.py:613: UserWarning: Checkpoint directory C:\Users\peter\anaconda3\envs\cv\Scripts\ptls-glove\checkpoints exists and is not empty.
#   rank_zero_warn(f"Checkpoint directory {dirpath} exists and is not empty.")
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# trx_tran_classic_no_disc_cat: TRAIN STARTS
# Sanity Checking: 0it [00:00, ?it/s]
# C:\Users\peter\anaconda3\envs\cv\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:224: PossibleUserWarning: The dataloader, val_dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 12 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# C:\Users\peter\anaconda3\envs\cv\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:224: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 12 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# {'loss': tensor(239.4499), 'seq_len': tensor(115.9300), 'valid/recall_top_k': tensor(0.2374)}
# trx_tran_classic_no_disc_cat: TRAIN ENDS, MODEL SAVED

# %%
	# python exp_pipeline.py $(CONFIG_PATH) --exp-name=baseline
	# python exp_pipeline.py $(CONFIG_PATH) --exp-name=quant_100_dist_common_emb_cat
	# python exp_pipeline.py $(CONFIG_PATH) --exp-name=quant_num_emb_dist_common_emb_cat
	# python exp_pipeline.py $(CONFIG_PATH) --exp-name=st_num_emb_dist_common_emb_sum
	# python exp_pipeline.py $(CONFIG_PATH) --exp-name=st_num_emb_dist_common_emb_mean
	# python exp_pipeline.py $(CONFIG_PATH) --exp-name=quant_100_dist_common_emb_sum
	# python exp_pipeline.py $(CONFIG_PATH) --exp-name=quant_100_dist_common_emb_mean
	# python exp_pipeline.py $(CONFIG_PATH) --exp-name=st_num_emb_dist_common_emb_cat
	# python exp_pipeline.py $(CONFIG_PATH) --exp-name=st_num_emb_dist_common_emb_mean
	# python exp_pipeline.py $(CONFIG_PATH) --exp-name=st_num_emb_dist_common_emb_sum

# %%
df_params
# Out:
# {'numeric_cols': [],
#  'cat_cols': ['amount_rur', 'small_group'],
#  'date_col': 'trans_date',
#  'cat_unique': [202, 730],
#  'id_col': 'client_id'}

# %%
for i in train_dl.train_dataloader():
    ddd = i
    break

# %%
seq_encoder.trx_encoder.__dict__
# Out:
# {'training': False,
#  '_parameters': OrderedDict(),
#  '_buffers': OrderedDict(),
#  '_non_persistent_buffers_set': set(),
#  '_backward_hooks': OrderedDict(),
#  '_is_full_backward_hook': None,
#  '_forward_hooks': OrderedDict(),
#  '_forward_pre_hooks': OrderedDict(),
#  '_state_dict_hooks': OrderedDict(),
#  '_load_state_dict_pre_hooks': OrderedDict(),
#  '_load_state_dict_post_hooks': OrderedDict(),
#  '_modules': OrderedDict([('embeddings',
#                TransEmbedding(
#                  (cat_table): ModuleDict(
#                    (small_group): Embedding(203, 3)
#                    (trans_date): Embedding(731, 3)
#                  )
#                  (forward_mlp): ModuleList(
#                    (0): Linear(in_features=3, out_features=3, bias=True)
#                    (1): Linear(in_features=3, out_features=3, bias=True)
#                  )
#                  (dropout): Dropout(p=0.2, inplace=False)
#                  (emb_dict): ModuleDict(
#                    (small_group): Embedding(203, 3)
#                    (trans_date): Embedding(731, 3)
#                  )
#                ))]),
#  'numeric_separate': False,
#  'numeric_features': [],
#  'device': 'cpu',
#  'algo': 'orig',
#  'esz': 3,
#  'agg_type': None,
#  'feature_names': ['small_group', 'trans_date']}

# %% [markdown]
# ### Get cosine-dist metric values on train/test datasets

# %%
df_params = {'numeric_cols': ['amount_rur'],
     'cat_cols': ['small_group'],
     'date_col': 'trans_date',
     'cat_unique': [202, 730],
     'id_col': 'client_id'}

# %%
experiments
# Out:
# [{'name': 'trx_tran_orig_no_disc',
#   'algo': 'orig',
#   'agg_type': None,
#   'nsep': False},
#  {'name': 'trx_tran_orig_deeptlf9',
#   'algo': 'orig',
#   'agg_type': None,
#   'nsep': False,
#   'disc': <ptls.preprocessing.deeptlf.deeptlf_discretizer.DeepTLFDisc at 0x1dc10669510>,
#   'nemb': False},
#  {'name': 'trx_tran_classic_deeptlf9_cat',
#   'algo': 'classic',
#   'agg_type': 'cat',
#   'nsep': False,
#   'disc': <ptls.preprocessing.deeptlf.deeptlf_discretizer.DeepTLFDisc at 0x1dc10669a20>,
#   'nemb': False},
#  {'name': 'trx_tran_classic_quant100_sum',
#   'algo': 'classic',
#   'agg_type': 'sum',
#   'nsep': False,
#   'disc': <ptls.preprocessing.baseline_discretizer.k_discretizer.KDiscretizer at 0x1dc1066b700>,
#   'nemb': False},
#  {'name': 'trx_tran_orig_quant100',
#   'algo': 'orig',
#   'agg_type': None,
#   'nsep': False,
#   'disc': <ptls.preprocessing.baseline_discretizer.k_discretizer.KDiscretizer at 0x1dc10669cc0>,
#   'nemb': False},
#  {'name': 'trx_tran_classic_quant100_cat',
#   'algo': 'classic',
#   'agg_type': 'cat',
#   'nsep': False,
#   'disc': <ptls.preprocessing.baseline_discretizer.k_discretizer.KDiscretizer at 0x1dc106687f0>,
#   'nemb': False},
#  {'name': 'trx_tran_classic_deeptlf9_sum',
#   'algo': 'classic',
#   'agg_type': 'sum',
#   'nsep': False,
#   'disc': <ptls.preprocessing.deeptlf.deeptlf_discretizer.DeepTLFDisc at 0x1dc1066bb20>,
#   'nemb': False},
#  {'name': 'trx_tran_classic_no_disc_cat',
#   'algo': 'classic',
#   'agg_type': 'cat',
#   'nsep': True},
#  {'name': 'basic_model_emb_16', 'nsep': True}]

# %%
experiments += [
    {
        'name' : 'basic_model_emb_16',
        'nsep' : True
    }
]

# %%
from lightgbm import LGBMClassifier
from sklearn.ensemble import RandomForestClassifier
res_metrics = []
N_TRIALS = 5

tasks = {'boosting' : LGBMClassifier(), 'r_forest' : RandomForestClassifier()}

def get_train_test_age_bins_scenario(df_params, train_embeds, test_embeds, train, test):
    data_path = "../data/age_bins"
    
    df_target = pd.read_csv(os.path.join(data_path, 'train_target.csv'))
    df_target = df_target.set_index(df_params["id_col"])
    df_target.rename(columns={"bins": "target"}, inplace=True)
    
    train_df = pd.DataFrame(data=train_embeds, columns=[f'embed_{i}' for i in range(train_embeds.shape[1])])
    train_df[df_params["id_col"]] = [x[df_params["id_col"]] for x in train]
    train_df = train_df.merge(df_target, how='left', on=df_params["id_col"])
    
    test_df = pd.DataFrame(data=test_embeds, columns=[f'embed_{i}' for i in range(test_embeds.shape[1])])
    test_df[df_params["id_col"]] = [x[df_params["id_col"]] for x in test]
    test_df = test_df.merge(df_target, how='left', on=df_params["id_col"])
    return train_df, test_df

for exp in experiments[:1]:
    print(exp['name'])
    data = copy.deepcopy(source_data)
    if 'disc' in exp:
        exp['disc'].fit(data)
    df_params = {'numeric_cols': ['amount_rur'],
     'cat_cols': ['small_group'],
     'date_col': 'trans_date',
     'cat_unique': [202, 730],
     'id_col': 'client_id'}
    if 'nemb' in exp and not exp['nemb']:
        df_params['cat_cols'] =  df_params['numeric_cols'] + df_params['cat_cols']
        df_params["cat_unique"] = (exp['disc'].k_bins if (type(exp['disc'].k_bins) is list) else [exp['disc'].k_bins] * len(df_params['numeric_cols'])) + df_params["cat_unique"]
        df_params['numeric_cols'] = []
    with open(f"../coles_prep_datasets/{exp['name']}_dataset_age_bins.pkl", "rb") as fl:
        dataset = pickle.load(fl)

    train, test = train_test_split(dataset, test_size=0.2, random_state=42)

    train, val = train_test_split(train, test_size=0.1, random_state=42)

    if 'glove_config' in exp:
        if not exp['nsep']:
            embedded_feats = df_params['numeric_cols'] + df_params['cat_cols'] + [df_params["date_col"]]
        else:
            embedded_feats = df_params['cat_cols'] + [df_params["date_col"]]
        folder_nm = f'../glove_embeddings/{exp["name"]}'[:-4] if exp['agg_type'] != 'mean' else f'../glove_embeddings/{exp["name"]}'[:-5]
        glove_embedding = GloveEmbedding(
            feature_names=embedded_feats,
            calculate_cooccur=False,
            embedding_folder=folder_nm,
            glove_params=exp['glove_config']
        )
        glove_embedding.load()
    
    seq_encoder = get_cat_encoder(df_params, agg_type=exp['agg_type'], num_emb_flag=exp['nemb'])
    #seq_encoder = get_trans_encoder(df_params, agg_type=exp['agg_type'], algo=exp['algo'], numeric_separate=exp['nsep'])
    #seq_encoder = get_glove_encoder(df_params, exp, glove_embedding)

    # if exp['name'] != 'basic_model_emb_16':
    #     seq_encoder = get_trans_encoder(df_params, agg_type=exp['agg_type'], algo=exp['algo'], numeric_separate=exp['nsep'])
    #     mx = torch.load(f"../models_coles/{exp['name']}_emb.pt")
    #     for fn in df_params['cat_cols'] + [df_params["date_col"]] + df_params['numeric_cols'] :
    #         if f'trx_encoder.embeddings.emb_dict.{fn}.weight' in mx:
    #             mx.pop(f'trx_encoder.embeddings.emb_dict.{fn}.weight')
    #     seq_encoder.load_state_dict(mx)
    # else:
    #     seq_encoder = get_basic_model_encoder(df_params)
    seq_encoder.load_state_dict(torch.load(f"../coles_models/{exp['name']}_age_bins.pt"))

    # metric = BatchRecallTopK(4)

    # train_embeds = None
    # test_embeds = None
    # #('train', train)
    # for ds_name, ds in [('test', test)]:
    #     dl = PtlsDataModule(
    #         test_data = ColesDataset(
    #                 MemoryMapDataset(
    #                     data=ds,
    #                     i_filters=[
    #                         SeqLenFilter(min_seq_len=25),
    #                     ],
    #                 ),
    #                 splitter=SampleSlices(
    #                     split_count=5,
    #                     cnt_min=25,
    #                     cnt_max=200,
    #                 ),
    #             ),
    #         train_num_workers=1,
    #         train_batch_size=256,
    #     )

    #     module = TestModule(
    #         model = seq_encoder,
    #         metrics = {"recall_top_k" : metric}
    #     )
    
    #     predictor = pl.Trainer(
    #             accelerator="gpu",
    #             enable_model_summary=False,
    #             logger=False
    #     )

    #     predictor.predict(module, dl)

    #     ds_metrics = module.get_metrics()

    #     for m in ds_metrics:
    #         res_metrics.append([exp['name'], ds_name, m, ds_metrics[m]])

    coles_model = CoLESModule(
            seq_encoder=seq_encoder,
    )

    inference_runner = pl.Trainer(
        accelerator="gpu",
        enable_progress_bar=True,
        enable_model_summary=False,
        logger=False
    )
    
    train_dl = inference_data_loader(train, num_workers=0, batch_size=256)
    train_embeds = torch.vstack(inference_runner.predict(coles_model, train_dl))
    
    test_dl = inference_data_loader(test, num_workers=0, batch_size=256)
    test_embeds = torch.vstack(inference_runner.predict(coles_model, test_dl))

    train_df, test_df = get_train_test_age_bins_scenario(df_params, train_embeds, test_embeds, train, test)

    for task_name, clf in tasks.items():
        sc_test = 0
        sc_train = 0
        num = 0
        for i in tqdm(range(N_TRIALS)):
            embed_columns = [x for x in train_df.columns if x.startswith('embed')]
            x_train, y_train = train_df[embed_columns], train_df['target']
            x_test, y_test = test_df[embed_columns], test_df['target']

            clf.fit(x_train, y_train)
            sc_test += clf.score(x_test, y_test)
            print(clf.score(x_test, y_test))
            #sc_train += clf.score(x_train, y_train)
            num += 1
            break

        #res_metrics.append([exp['name'], 'train', f"acc_{task_name}", sc_train/num])
        res_metrics.append([exp['name'], 'test', f"acc_{task_name}", sc_test/num])

    #report = pd.DataFrame(res_metrics, columns = ['exp_name', 'dataset', 'metric', 'value'])
   # report.to_csv('../coles_experiments/report_jn1.csv')
# Out:
# quant_100_dist_common_emb_myparams1_cat
# C:\Users\toppc\AppData\Local\Temp\ipykernel_18412\2143705687.py:72: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   seq_encoder.load_state_dict(torch.load(f"../coles_models/{exp['name']}_age_bins.pt"))
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# C:\Users\toppc\.conda\envs\torch_cu118\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:425: The 'predict_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=15` in the `DataLoader` to improve performance.
# Predicting: |          | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |          | 0/? [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.012712 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 65280
# [LightGBM] [Info] Number of data points in the train set: 27000, number of used features: 256
# [LightGBM] [Info] Start training from score -1.387925
# [LightGBM] [Info] Start training from score -1.388074
# [LightGBM] [Info] Start training from score -1.385406
# [LightGBM] [Info] Start training from score -1.383779
# 0.7053333333333334
#   0%|          | 0/5 [00:00<?, ?it/s]
# 0.7741666666666667

# %%
df_params
# Out:
# {'numeric_cols': [],
#  'cat_cols': ['amount_rur', 'small_group'],
#  'date_col': 'trans_date',
#  'cat_unique': [202, 730],
#  'id_col': 'client_id'}

# %%
mx = torch.load(f"../models_coles/{exp['name']}_emb.pt")
for fn in df_params['cat_cols'] + [df_params["date_col"]]:
    mx.pop(f'trx_encoder.embeddings.emb_dict.{fn}.weight')

# %%
torch.load(f"../models_coles/{exp['name']}_emb.pt").pop('trx_encoder.embeddieight')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 torch.load(f"../models_coles/{exp['name']}_emb.pt").pop('trx_encoder.embeddieight')
#
# KeyError: 'trx_encoder.embeddieight'

# %%
r = []
for j in range(3):
    r.append(np.random.random(18) * 0.1 + 0.9)
    
pd.DataFrame(r, columns=['a' + str(i) for i in range(18)]).to_excel('rand.xlsx')

# %%
reps = []
for i in range(1, 3):
    reps.append(pd.read_csv(f'..//coles_report/experiments/report_trans{i}.csv'))
reps = pd.concat(reps).drop(columns = ['Unnamed: 0'])

# %%
a = list(map(lambda x: x.split('_'), reps.exp_name.values))
reps['aggt'] = [i[-1] for i in a]
#reps['mod'] = [i[1] for i in a]
#reps['cfg'] = [i[2] for i in a]

reps.sort_values(by=['aggt', 'exp_name', 'dataset', 'metric'], ascending=False)[['aggt', 'exp_name', 'metric', 'value']].to_excel('tran1.xlsx')

# %%
pd.read_csv(f'..//coles_report/experiments/report_gender_baseline.csv')
# Out:
#    Unnamed: 0                   exp_name dataset        metric     value
# 0           0  basic_model_emb_16_gender    test  recall_top_k  0.852669
# 1           1  basic_model_emb_16_gender    test  acc_boosting  0.440333
# 2           2  basic_model_emb_16_gender    test  acc_r_forest  0.434133

# %%
reps = []
for i in range(2, 3):
    reps.append(pd.read_csv(f'..//coles_report/experiments/report_gender{i}.csv'))
reps = pd.concat(reps).drop(columns = ['Unnamed: 0'])

# %%
reps.head(60)
# Out:
#                                exp_name dataset        metric     value
# 0      glove_emb_cfg2_no_num_gender_cat    test  recall_top_k  0.834742
# 1      glove_emb_cfg2_no_num_gender_cat    test  acc_boosting  0.443333
# 2      glove_emb_cfg2_no_num_gender_cat    test  acc_r_forest  0.435933
# 3        glove_emb_cfg1_ST20_gender_cat    test  recall_top_k  0.832981
# 4        glove_emb_cfg1_ST20_gender_cat    test  acc_boosting  0.442667
# 5        glove_emb_cfg1_ST20_gender_cat    test  acc_r_forest  0.436000
# 6        glove_emb_cfg1_ST20_gender_sum    test  recall_top_k  0.714622
# 7        glove_emb_cfg1_ST20_gender_sum    test  acc_boosting  0.436000
# 8        glove_emb_cfg1_ST20_gender_sum    test  acc_r_forest  0.444600
# 9       glove_emb_cfg1_ST20_gender_mean    test  recall_top_k  0.555600
# 10      glove_emb_cfg1_ST20_gender_mean    test  acc_boosting  0.434667
# 11      glove_emb_cfg1_ST20_gender_mean    test  acc_r_forest  0.433533
# 12   glove_emb_cfg2_quant100_gender_cat    test  recall_top_k  0.872716
# 13   glove_emb_cfg2_quant100_gender_cat    test  acc_boosting  0.432333
# 14   glove_emb_cfg2_quant100_gender_cat    test  acc_r_forest  0.427867
# 15   glove_emb_cfg2_quant100_gender_sum    test  recall_top_k  0.688142
# 16   glove_emb_cfg2_quant100_gender_sum    test  acc_boosting  0.416667
# 17   glove_emb_cfg2_quant100_gender_sum    test  acc_r_forest  0.428067
# 18  glove_emb_cfg2_quant100_gender_mean    test  recall_top_k  0.652424
# 19  glove_emb_cfg2_quant100_gender_mean    test  acc_boosting  0.424667
# 20  glove_emb_cfg2_quant100_gender_mean    test  acc_r_forest  0.423133
# 21   glove_emb_cfg2_deeptlf9_gender_cat    test  recall_top_k  0.827830
# 22   glove_emb_cfg2_deeptlf9_gender_cat    test  acc_boosting  0.438667
# 23   glove_emb_cfg2_deeptlf9_gender_cat    test  acc_r_forest  0.438733
# 24   glove_emb_cfg2_deeptlf9_gender_sum    test  recall_top_k  0.696921
# 25   glove_emb_cfg2_deeptlf9_gender_sum    test  acc_boosting  0.430000
# 26   glove_emb_cfg2_deeptlf9_gender_sum    test  acc_r_forest  0.425267
# 27  glove_emb_cfg2_deeptlf9_gender_mean    test  recall_top_k  0.558119
# 28  glove_emb_cfg2_deeptlf9_gender_mean    test  acc_boosting  0.421000
# 29  glove_emb_cfg2_deeptlf9_gender_mean    test  acc_r_forest  0.425400

# %%
a = list(map(lambda x: x.split('_'), reps.exp_name.values))
reps['aggt'] = [i[-1] for i in a]
#reps['mod'] = [i[1] for i in a]
#reps['cfg'] = [i[2] for i in a]

reps.sort_values(by=['aggt', 'exp_name', 'dataset', 'metric'], ascending=False)[['aggt', 'exp_name', 'metric', 'value']].to_excel('gender2.xlsx')

# %%
a = list(map(lambda x: x.split('_'), reps.exp_name.values))
reps['aggt'] = [i[-1] for i in a]
reps['mod'] = [i[1] for i in a]
#reps['cfg'] = [i[2] for i in a]

reps.sort_values(by=['aggt', 'name', 'mod', 'dataset', 'metric'], ascending=False)[['aggt', 'name', 'mod', 'metric', 'value']].to_excel(f'..//coles_report/experiments/report_glove.xlsx')

# %%
# %%time

dataset = preprocessor.fit_transform(data)
# Out:
# CPU times: total: 14.7 s
# Wall time: 15.9 s

# %%
import pickle

with open('preprocessor.p', 'wb') as f:
    pickle.dump(preprocessor, f)

# %%
dataset = sorted(dataset, key=lambda x: x[df_params['id_col']])

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(dataset, test_size=0.2, random_state=42)

len(train), len(test)
# Out:
# (12000, 3000)

# %%
del dataset

# %% [markdown]
# ## Embedding training

# %% [markdown]
# Model training in our framework organised via pytorch-lightning (pl) framework.
# The key parts of neural networks training in pl are:
#
#     * model (`pytorch_lightning.LightningModule`)
#     * data loader (`torch.utils.data.DataLoader`)
#     * trainer (`pytorch_lightning.Trainer`)
#
# For futher details check https://pytorchlightning.ai/

# %% [markdown]
# ### Model definition

# %%
df_params
# Out:
# {'numeric_cols': ['amount'],
#  'cat_cols': ['mcc_code', 'tr_type'],
#  'cat_unique': [184, 77, 457],
#  'date_col': 'tr_datetime',
#  'id_col': 'customer_id'}

# %%
from functools import partial
from ptls.nn import RnnSeqEncoder, TrxEncoder
from ptls.nn.trx_encoder.trx_encoder_glove import TrxEncoderGlove
from ptls.frames.coles import CoLESModule
import ptls
import torch

def get_basic_model_encoder(df_params):
    embeddings=dict()
    for i, f in enumerate(df_params["cat_cols"] + [df_params["date_col"]]):
        embeddings[f] = {'in' : df_params["cat_unique"][i], 'out' : 16}
    
    trx_encoder_params = dict(
        embeddings_noise=0.003,
        numeric_values=dict([(fe, 'identity') for fe in df_params['numeric_cols']]),
        embeddings=embeddings
    )
    
    seq_encoder = RnnSeqEncoder(
        trx_encoder=TrxEncoder(**trx_encoder_params),
        hidden_size=256,
        type='gru',
    )
    
    return seq_encoder

def get_glove_model_encoder(agg_type):
    seq_encoder = RnnSeqEncoder(
        trx_encoder=TrxEncoderGlove(glove_embedding, agg_type=agg_type),
        hidden_size=256,
        type='gru',
    )
    return seq_encoder


#seq_encoder = get_basic_model_encoder(df_params)
seq_encoder = get_glove_model_encoder(agg_type="sum")

model = CoLESModule(
    seq_encoder=seq_encoder,
    optimizer_partial=partial(torch.optim.Adam, lr=0.001),
    lr_scheduler_partial=partial(torch.optim.lr_scheduler.StepLR, step_size=30, gamma=0.9),
)

# %% [markdown]
# ### Data loader

# %%
from ptls.data_load.datasets import MemoryMapDataset
from ptls.data_load.iterable_processing import SeqLenFilter
from ptls.frames.coles import ColesDataset
from ptls.frames.coles.split_strategy import SampleSlices
from ptls.frames import PtlsDataModule

train_dl = PtlsDataModule(
    train_data=ColesDataset(
        MemoryMapDataset(
            data=train,
            i_filters=[
                SeqLenFilter(min_seq_len=25),
            ],
        ),
        splitter=SampleSlices(
            split_count=5,
            cnt_min=25,
            cnt_max=200,
        ),
    ),
    train_num_workers=1,
    train_batch_size=256,
)

# %% [markdown]
# ### Trainer

# %%
import torch
import pytorch_lightning as pl

import logging

trainer = pl.Trainer(
    max_epochs=15,
    accelerator="gpu",
    #devices=1,
    enable_progress_bar=True,
)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs

# %% [markdown]
# ### Training

# %%
# %%time
print(f'logger.version = {trainer.logger.version}')
trainer.fit(model, train_dl)
print(trainer.logged_metrics)
# Out:
# C:\Users\peter\anaconda3\envs\cv\lib\site-packages\pytorch_lightning\trainer\configuration_validator.py:108: PossibleUserWarning: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
#   rank_zero_warn(
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name               | Type            | Params
# -------------------------------------------------------
# 0 | _loss              | ContrastiveLoss | 0
# 1 | _seq_encoder       | RnnSeqEncoder   | 270 K
# 2 | _validation_metric | BatchRecallTopK | 0
# 3 | _head              | Head            | 0
# -------------------------------------------------------
# 210 K     Trainable params
# 60.0 K    Non-trainable params
# 270 K     Total params
# 1.083     Total estimated model params size (MB)
# logger.version = 175
# C:\Users\peter\anaconda3\envs\cv\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:224: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 12 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# C:\Users\peter\anaconda3\envs\cv\lib\site-packages\pytorch_lightning\trainer\trainer.py:1609: PossibleUserWarning: The number of training batches (46) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#   rank_zero_warn(
# Training: 0it [00:00, ?it/s]
# `Trainer.fit` stopped: `max_epochs=15` reached.
# {'loss': tensor(257.4940), 'seq_len': tensor(97.3034)}
# CPU times: total: 1min 58s
# Wall time: 7min 6s

# %% [markdown]
# ### Save sequence encoder for other experiments

# %%
torch.save(seq_encoder.state_dict(), "coles-emb.pt")

# %% [markdown]
# ## Inference

# %%
# embedding inference

train_dl = inference_data_loader(train, num_workers=0, batch_size=256)
train_embeds = torch.vstack(trainer.predict(model, train_dl, ))

test_dl = inference_data_loader(test, num_workers=0, batch_size=256)
test_embeds = torch.vstack(trainer.predict(model, test_dl))

train_embeds.shape, test_embeds.shape
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# C:\Users\peter\anaconda3\envs\cv\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:224: PossibleUserWarning: The dataloader, predict_dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 12 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Predicting: 46it [00:00, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 46it [00:00, ?it/s]
# (torch.Size([12000, 256]), torch.Size([3000, 256]))

# %%
def get_train_test_age_bins_scenario(df_params, train_embeds, test_embeds):
    data_path = "data/age_bins"
    
    df_target = pd.read_csv(os.path.join(data_path, 'train_target.csv'))
    df_target = df_target.set_index(df_params["id_col"])
    df_target.rename(columns={"bins": "target"}, inplace=True)
    
    train_df = pd.DataFrame(data=train_embeds, columns=[f'embed_{i}' for i in range(train_embeds.shape[1])])
    train_df[df_params["id_col"]] = [x[df_params["id_col"]] for x in train]
    train_df = train_df.merge(df_target, how='left', on=df_params["id_col"])
    
    test_df = pd.DataFrame(data=test_embeds, columns=[f'embed_{i}' for i in range(test_embeds.shape[1])])
    test_df[df_params["id_col"]] = [x[df_params["id_col"]] for x in test]
    test_df = test_df.merge(df_target, how='left', on=df_params["id_col"])
    return train_df, test_df

def get_train_test_gender_scenario(df_params, train_embeds, test_embeds):
    data_path = "data/gender"
    
    df_target = pd.read_csv(os.path.join(data_path, 'gender_train.csv'))
    df_target = df_target.set_index(df_params["id_col"])
    df_target.rename(columns={"gender": "target"}, inplace=True)
    
    train_df = pd.DataFrame(data=train_embeds, columns=[f'embed_{i}' for i in range(train_embeds.shape[1])])
    train_df[df_params["id_col"]] = [x[df_params["id_col"]] for x in train]
    train_df = train_df.merge(df_target, how='left', on=df_params["id_col"])
    
    test_df = pd.DataFrame(data=test_embeds, columns=[f'embed_{i}' for i in range(test_embeds.shape[1])])
    test_df[df_params["id_col"]] = [x[df_params["id_col"]] for x in test]
    test_df = test_df.merge(df_target, how='left', on=df_params["id_col"])
    train_df = train_df.fillna(2)
    test_df = test_df.fillna(2)
    return train_df, test_df

# %%
import os
import pandas as pd

data_path = 'data/rosbank'

data_train = pd.read_csv(os.path.join(data_path, 'train.csv'))
data_test = pd.read_csv(os.path.join(data_path, 'test.csv'))

df_trx = get_df_trx(data_train, data_test)
df_trx = df_trx.fillna("unknown_type")
df_target = get_df_target(data_train)

# %%
# join target and embeddings

#df_target = pd.read_csv(os.path.join(data_path, 'train_target.csv'))
#df_target = pd.read_csv(os.path.join(data_path, 'gender_train.csv'))
#df_target = df_target.rename(columns={"customer_id" : "client_id"})
#df_target = df_target.set_index('client_id')
#df_target.rename(columns={"bins": "target"}, inplace=True)
df_target.rename(columns={"target_flag": "target"}, inplace=True)

train_df = pd.DataFrame(data=train_embeds, columns=[f'embed_{i}' for i in range(train_embeds.shape[1])])
train_df['client_id'] = [x['client_id'] for x in train]
#train_df = train_df.merge(df_target, how='left', on='client_id')

test_df = pd.DataFrame(data=test_embeds, columns=[f'embed_{i}' for i in range(test_embeds.shape[1])])
test_df['client_id'] = [x['client_id'] for x in test]
#test_df = test_df.merge(df_target, how='left', on='client_id')

print(train_df.shape, test_df.shape)
# Out:
# (8173, 257) (2044, 257)

# %%
df_target["client_id"] = df_target.index

# %%
train_df = train_df.merge(df_target, how='left', on='client_id')

# %%
test_df = test_df.merge(df_target, how='left', on='client_id')

# %% [markdown]
# Obtained embeddings can be used as features for model training
#
# For example:

# %%
from sklearn.ensemble import RandomForestClassifier

metrics_on_tasks = []

for exp in experiments:

    train_dl = inference_data_loader(train, num_workers=0, batch_size=256)
    train_embeds = torch.vstack(trainer.predict(model, train_dl, ))
    
    test_dl = inference_data_loader(test, num_workers=0, batch_size=256)
    test_embeds = torch.vstack(trainer.predict(model, test_dl))


    train_df, test_df = get_train_test_gender_scenario(df_params, train_embeds, test_embeds)
    
    sc = 0
    num = 0
    for i in range(10):
        embed_columns = [x for x in train_df.columns if x.startswith('embed')]
        x_train, y_train = train_df[embed_columns], train_df['target']
        x_test, y_test = test_df[embed_columns], test_df['target']
        
        clf = RandomForestClassifier()
        clf.fit(x_train, y_train)
        sc += clf.score(x_test, y_test)
        num += 1
    sc/num
# Out:
# 0.4342

# %%
#glove_cat 0.75 100 tree_binning 3t
cat 0.5846666666666667
mean 0.5629666666666667
sum 0.5711

#glove_cat 0.75 5000 tree_binning 6t
cat 0.5912666666666666
mean 0.5697333333333333
sum 0.5792666666666667

#glove_cat 0.75 15000 tree_binning 9t
cat 0.5797666666666668
mean 0.5720000000000001
sum 0.5781666666666667

###gender

#glove_cat 0.75 100 tree_binning 3t
cat 0.438
mean 0.4342
sum 0.5711

#glove_cat 0.75 5000 tree_binning 6t
cat 0.4500333333333333
mean 0.4312666666666667
sum 0.4416333333333333

#glove_cat 0.75 15000 tree_binning 9t
cat 0.4503666666666667
mean 0.433
sum 0.44053333333333333

# %%
#normal
0.48356164383561645

#glove_mean 0.75 1000 100 bins
mean 0.4900195694716243
sum 0.49735812133072405
cat 0.4990215264187867

#glove_mean 0.75 5000 150 bins
mean 0.49549902152641884
sum 0.4918786692759296
cat 0.5001956947162427
