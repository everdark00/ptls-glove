# %%
import hydra
import yaml
from omegaconf import DictConfig
import pytorch_lightning as pl
import os
import sys
import pickle

from pytorch_lightning.callbacks import LearningRateMonitor
from pytorch_lightning.callbacks import ModelCheckpoint
from pytorch_lightning.loggers import TensorBoardLogger

with open('ptls_config.yaml', 'rb') as fl:
    conf = DictConfig(yaml.safe_load(fl))

# %%
with open('../data/train_trx.parquet', 'rb') as fl:
    data = pickle.load(fl)

# %%
dm = hydra.utils.instantiate(conf.data_module)

# %%
#train
if 'seed_everything' in conf:
    pl.seed_everything(conf.seed_everything)

model = hydra.utils.instantiate(conf.pl_module)
#dm = hydra.utils.instantiate(conf.data_module)

_trainer_params = conf.trainer
_trainer_params_additional = {}

_trainer_params_callbacks = []

lr_monitor = LearningRateMonitor(logging_interval='step')
_trainer_params_callbacks.append(lr_monitor)

if len(_trainer_params_callbacks) > 0:
    _trainer_params_additional['callbacks'] = _trainer_params_callbacks
    
trainer = pl.Trainer(**_trainer_params, **_trainer_params_additional)
trainer.fit(model, dm)

if 'model_path' in conf:
    torch.save(model.seq_encoder, conf.model_path)
# Out:
# Seed set to 42
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# C:\Users\toppc\.conda\envs\torch_cu118\Lib\site-packages\pytorch_lightning\trainer\connectors\logger_connector\logger_connector.py:76: Starting from v1.9.0, `tensorboardX` has been removed as a dependency of the `pytorch_lightning` package, due to potential conflicts with other packages in the ML ecosystem. For this reason, `logger=True` will use `CSVLogger` as the default logger, unless the `tensorboard` or `tensorboardX` packages are found. Please `pip install lightning[extra]` or one of them to enable TensorBoard support by default
# You are using a CUDA device ('NVIDIA GeForce RTX 4070 Ti SUPER') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name               | Type            | Params | Mode
# ---------------------------------------------------------------
# 0 | _loss              | ContrastiveLoss | 0      | train
# 1 | _seq_encoder       | RnnSeqEncoder   | 3.4 M  | train
# 2 | _validation_metric | BatchRecallTopK | 0      | train
# 3 | _head              | Head            | 0      | train
# ---------------------------------------------------------------
# 3.4 M     Trainable params
# 0         Non-trainable params
# 3.4 M     Total params
# 13.557    Total estimated model params size (MB)
# 19        Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# `Trainer.fit` stopped: `max_epochs=150` reached.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 23
#      20 trainer.fit(model, dm)
#      22 if 'model_path' in conf:
# ---> 23     torch.save(model.seq_encoder, conf.model_path)
#
# NameError: name 'torch' is not defined

# %%
#inference
import logging

import hydra
import pandas as pd
import pytorch_lightning as pl
import torch
import torch.multiprocessing
from omegaconf import DictConfig
from torch.utils.data.dataloader import DataLoader

from ptls.data_load.utils import collate_feature_dict
from ptls.frames.inference_module import InferenceModule

def save_scores(df_scores, output_conf):
    output_name = output_conf.path
    output_format = output_conf.format

    output_path = f'{output_name}.{output_format}'

    if output_format == 'pickle':
        df_scores.to_pickle(output_path)
    elif output_format == 'csv':
        df_scores.to_csv(output_path, sep=',', header=True, index=False)
    elif output_format == 'parquet':
        df_scores.to_parquet(output_path)
    else:
        print('error')


if 'seed_everything' in conf:
    pl.seed_everything(conf.seed_everything)

seq_encoder = hydra.utils.instantiate(conf.inference.seq_encoder)
if type(seq_encoder) is DictConfig and seq_encoder.get('load_from_checkpoint', False):
    pl_module = hydra.utils.instantiate(conf.pl_module)
    pl_module.load_state_dict(torch.load(seq_encoder['f'])['state_dict'])
    seq_encoder = pl_module.seq_encoder
model = InferenceModule(
    model=seq_encoder,
    pandas_output=True, model_out_name='emb',
)
model.model.is_reduce_sequence = True

dataset_inference = hydra.utils.instantiate(conf.inference.dataset)
inference_dl = DataLoader(
    dataset=dataset_inference,
    collate_fn=collate_feature_dict,
    shuffle=False,
    num_workers=conf.inference.get('num_workers', 0),
    batch_size=conf.inference.get('batch_size', 128),
)

if torch.cuda.is_available():
    accelerator = "cuda"
    devices = 1
else:
    accelerator = "cpu"
    devices = 0

df_scores = pl.Trainer(accelerator=accelerator, devices=devices, max_epochs=-1).predict(model, inference_dl)
df_scores = pd.concat(df_scores, axis=0)

save_scores(df_scores, conf.inference.output)
# Out:
# Seed set to 42
# C:\Users\toppc\.conda\envs\torch_cu118\Lib\site-packages\hydra\_internal\instantiate\_instantiate2.py:92: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return _target_(*args, **kwargs)
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# C:\Users\toppc\.conda\envs\torch_cu118\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:420: Consider setting `persistent_workers=True` in 'predict_dataloader' to speed up the dataloader worker initialization.
# Predicting: |          | 0/? [00:00<?, ?it/s]

# %%
with open('../data/embeddings/mles_embeddings.pickle', 'rb') as fl:
    embeds = pickle.load(fl)

embeds.customer_id = embeds.customer_id.astype('int64')

target = pd.read_csv('../data/gender/gender_train.csv').drop(columns=['Unnamed: 0'])
test_ids = pd.read_csv('../data/test_ids.csv')
train_ids = pd.DataFrame({'customer_id' : list(set(embeds.customer_id.values) - set(test_ids.customer_id.values))})

embeds = embeds.merge(target, on='customer_id', how='inner')

train_df = embeds.merge(train_ids, on='customer_id', how='inner').rename(columns={'gender' : 'target'})
test_df = embeds.merge(test_ids, on='customer_id', how='inner').rename(columns={'gender' : 'target'})

# %%
embeds = embeds.merge(target, on='customer_id', how='inner')

train_df = embeds.merge(train_ids, on='customer_id', how='inner').rename(columns={'gender' : 'target'})
test_df = embeds.merge(test_ids, on='customer_id', how='inner').rename(columns={'gender' : 'target'})

# %%
train_df
# Out:
#       customer_id  emb_0000  emb_0001  emb_0002  emb_0003  emb_0004  emb_0005  \
# 0        10058778 -0.659025 -0.999930 -0.013956  0.289240 -0.017789 -0.011142
# 1        10230827 -0.857736 -0.999987 -0.028047 -0.023356 -0.004569  0.001457
# 2        11681378 -0.794531 -0.999997 -0.127196  0.316811 -0.084344  0.016344
# 3        14123285 -0.526916 -0.999974 -0.042490  0.166428  0.034522 -0.034639
# 4        16536678 -0.999095 -0.997538  0.004072 -0.005387  0.037502 -0.005258
# ...           ...       ...       ...       ...       ...       ...       ...
# 7555     96649358 -0.275459 -0.999819  0.029100 -0.012849 -0.077690  0.003478
# 7556     97619321 -0.849478 -0.999671 -0.016505  0.073108 -0.081246  0.006040
# 7557     98165656 -0.755762 -0.999936  0.022088  0.051181  0.002524  0.005706
# 7558     98408171 -0.981090 -0.997253  0.931196  0.045892 -0.024214  0.002786
# 7559     99984336 -0.622022 -0.997283 -0.023657  0.054651  0.005519 -0.002682
#
#       emb_0006  emb_0007  emb_0008  ...  emb_1015  emb_1016  emb_1017  \
# 0    -0.147377 -0.012317  0.063469  ...  0.026012  0.952506 -0.005079
# 1     0.122885 -0.022659  0.023860  ...  0.054398  0.990353  0.011602
# 2     0.057524 -0.011266 -0.111917  ...  0.036370  0.895815  0.123837
# 3     0.081142 -0.083523  0.084043  ...  0.069895  0.992014 -0.005653
# 4    -0.010248  0.116659  0.026855  ...  0.083969  0.958235  0.001020
# ...        ...       ...       ...  ...       ...       ...       ...
# 7555  0.077346  0.000998 -0.024820  ...  0.091327  0.972289  0.004735
# 7556 -0.096665 -0.180980 -0.125174  ...  0.047542  0.944912  0.016983
# 7557 -0.002312  0.091716 -0.025516  ...  0.075486  0.838851  0.862938
# 7558  0.034886  0.050000 -0.006407  ...  0.055503  0.972233  0.033353
# 7559 -0.118235  0.052870 -0.049513  ...  0.028804  0.969285  0.000433
#
#       emb_1018  emb_1019  emb_1020  emb_1021  emb_1022  emb_1023  target
# 0     0.002005  0.544288 -0.770644 -0.131604 -0.065310 -0.014201       1
# 1    -0.005946 -0.085316  0.133903 -0.040571  0.070587 -0.176885       0
# 2     0.010396  0.252992 -0.041481 -0.195868 -0.024594 -0.076999       1
# 3    -0.023697 -0.021593  0.115210 -0.097603 -0.007214 -0.065185       0
# 501  0.003183  0.000700  0.837390  0.016546 -0.098680 -0.513867 -0.488545
# 502  0.003579 -0.004253  0.640458  0.042011 -0.052643  0.118728  0.009732
# 503  0.005618  0.000578  0.709149  0.029097 -0.089733  0.054439 -0.409179
#
# [15000 rows x 1025 columns]

# %%
target = pd.read_csv('../data/gender/gender_train.csv').drop(columns=['Unnamed: 0'])
target
# Out:
#       customer_id  gender
# 0        10928546       1
# 1        69348468       1
# 2        61009479       0
# 3        74045822       0
# 4        27979606       1
# ...           ...     ...
# 8395     90417572       0
# 8396     66837341       0
# 8397     10758984       1
# 8398     11376556       0
# 8399     29190649       0
#
# [8400 rows x 2 columns]

# %%
import pandas as pd
test_ids = pd.read_csv('../data/test_ids.csv')

# %%
test_ids
# Out:
#      customer_id
# 0          49793
# 1         104032
# 2         126935
# 3         218079
# 4         340557
# ..           ...
# 835     99415717
# 836     99590294
# 837     99717689
# 838     99882949
# 839     99915912
#
# [840 rows x 1 columns]

# %%
#boosting validation:

import os

import luigi
import hydra

from omegaconf import DictConfig, OmegaConf
from embeddings_validation import ReportCollect
from embeddings_validation.config import Config
from embeddings_validation.tasks.fold_splitter import FoldSplitter

# %%
with open('ptls_embedding_validation.yaml', 'rb') as fl:
    conf = DictConfig(yaml.safe_load(fl))

conf.workers = 5
if conf.workers is None: raise AttributeError('Define the number of workers: +workers=4')
conf.total_cpu_count = 10
if conf.total_cpu_count is None: raise AttributeError('Define the number of cpu on your machine: +total_cpu_count=8')

config = Config.get_conf(conf)

if conf.get('split_only', False):
    task = FoldSplitter(
        conf=config,
    )
else:
    task = ReportCollect(
        conf=config,
        total_cpu_count=conf['total_cpu_count'],
    )
luigi.build([task], workers=conf['workers'],
                    local_scheduler=conf.get('local_scheduler', True),
                    log_level=conf.get('log_level', 'INFO'))
# Out:
# C:\Users\toppc\.conda\envs\torch_cu118\Lib\site-packages\luigi\parameter.py:296: UserWarning: Parameter "conf" with value "<embeddings_validation.config.Config object at 0x0000020EF6598380>" is not of type string.
#   warnings.warn('Parameter "{}" with value "{}" is not of type string.'.format(param_name, param_value))
# INFO: Informed scheduler that task   ReportCollect__embeddings_vali_20_0110b24ea1   has status   PENDING
# INFO: Informed scheduler that task   ReportByFolds__embeddings_vali_mles_embeddings_lgbm_5d1b433d2e   has status   PENDING
# INFO: Informed scheduler that task   FoldEstimator__embeddings_vali_mles_embeddings_4_020bb69f0a   has status   PENDING
# INFO: Informed scheduler that task   FoldSplitter__embeddings_vali_7a864fe7f9   has status   DONE
# INFO: Informed scheduler that task   FoldEstimator__embeddings_vali_mles_embeddings_3_a29dffe1a9   has status   PENDING
# INFO: Informed scheduler that task   FoldEstimator__embeddings_vali_mles_embeddings_2_3609f235b2   has status   PENDING
# INFO: Informed scheduler that task   FoldEstimator__embeddings_vali_mles_embeddings_1_57ba1da0cc   has status   PENDING
# INFO: Informed scheduler that task   FoldEstimator__embeddings_vali_mles_embeddings_0_1f90cc901e   has status   PENDING
# INFO: Done scheduling tasks
# INFO: Running Worker with 10 processes
# INFO: Informed scheduler that task   FoldEstimator__embeddings_vali_mles_embeddings_4_020bb69f0a   has status   FAILED
# INFO: Informed scheduler that task   FoldEstimator__embeddings_vali_mles_embeddings_3_a29dffe1a9   has status   FAILED
# INFO: Worker Worker(salt=590158509, workers=10, host=DESKTOP-287JIAK, username=toppc, pid=6948) was stopped. Shutting down Keep-Alive thread
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~\.conda\envs\torch_cu118\Lib\site-packages\luigi\interface.py:177, in _schedule_and_run(tasks, worker_scheduler_factory, override_defaults)
#     176     logger.info('Done scheduling tasks')
# --> 177     success &= worker.run()
#     178 luigi_run_result = LuigiRunResult(worker, success)
#
# File ~\.conda\envs\torch_cu118\Lib\site-packages\luigi\worker.py:1254, in Worker.run(self)
#    1253 else:
# -> 1254     self._handle_next_task()
#    1255     continue
#
# File ~\.conda\envs\torch_cu118\Lib\site-packages\luigi\worker.py:1113, in Worker._handle_next_task(self)
#    1111 try:
#    1112     task_id, status, expl, missing, new_requirements = (
# -> 1113         self._task_result_queue.get(
#    1114             timeout=self._config.wait_interval))
#    1115 except Queue.Empty:
#
# File ~\.conda\envs\torch_cu118\Lib\multiprocessing\queues.py:113, in Queue.get(self, block, timeout)
#     112 timeout = deadline - time.monotonic()
# --> 113 if not self._poll(timeout):
#     114     raise Empty
#
# File ~\.conda\envs\torch_cu118\Lib\multiprocessing\connection.py:257, in _ConnectionBase.poll(self, timeout)
#     256 self._check_readable()
# --> 257 return self._poll(timeout)
#
# File ~\.conda\envs\torch_cu118\Lib\multiprocessing\connection.py:346, in PipeConnection._poll(self, timeout)
#     345     return True
# --> 346 return bool(wait([self], timeout))
#
# File ~\.conda\envs\torch_cu118\Lib\multiprocessing\connection.py:1084, in wait(object_list, timeout)
#    1082                 timeout = 0
# -> 1084     ready_handles = _exhaustive_wait(waithandle_to_obj.keys(), timeout)
#    1085 finally:
#    1086     # request that overlapped reads stop
#
# File ~\.conda\envs\torch_cu118\Lib\multiprocessing\connection.py:1016, in _exhaustive_wait(handles, timeout)
#    1015 while L:
# -> 1016     res = _winapi.WaitForMultipleObjects(L, False, timeout)
#    1017     if res == WAIT_TIMEOUT:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 20
#      15 else:
#      16     task = ReportCollect(
#      17         conf=config,
#      18         total_cpu_count=conf['total_cpu_count'],
#      19     )
# ---> 20 luigi.build([task], workers=conf['workers'],
#      21                     local_scheduler=conf.get('local_scheduler', True),
#      22                     log_level=conf.get('log_level', 'INFO'))
#
# File ~\.conda\envs\torch_cu118\Lib\site-packages\luigi\interface.py:243, in build(tasks, worker_scheduler_factory, detailed_summary, **env_params)
#     240 if "no_lock" not in env_params:
#     241     env_params["no_lock"] = True
# --> 243 luigi_run_result = _schedule_and_run(tasks, worker_scheduler_factory, override_defaults=env_params)
#     244 return luigi_run_result if detailed_summary else luigi_run_result.scheduling_succeeded
#
# File ~\.conda\envs\torch_cu118\Lib\site-packages\luigi\interface.py:173, in _schedule_and_run(tasks, worker_scheduler_factory, override_defaults)
#     171 success = True
#     172 logger = logging.getLogger('luigi-interface')
# --> 173 with worker:
#     174     for t in tasks:
#     175         success &= worker.add(t, env_params.parallel_scheduling, env_params.parallel_scheduling_processes)
#
# File ~\.conda\envs\torch_cu118\Lib\site-packages\luigi\worker.py:658, in Worker.__exit__(self, type, value, traceback)
#     656 for task in self._running_tasks.values():
#     657     if task.is_alive():
# --> 658         task.terminate()
#     659 self._task_result_queue.close()
#     660 return False
#
# File ~\.conda\envs\torch_cu118\Lib\site-packages\luigi\worker.py:275, in TaskProcess.terminate(self)
#     273 # default terminate() doesn't cleanup child processes, it orphans them.
#     274 try:
# --> 275     return self._recursive_terminate()
#     276 except ImportError:
#     277     return super(TaskProcess, self).terminate()
#
# File ~\.conda\envs\torch_cu118\Lib\site-packages\luigi\worker.py:260, in TaskProcess._recursive_terminate(self)
#     258 # terminate parent. Give it a chance to clean up
#     259 super(TaskProcess, self).terminate()
# --> 260 parent.wait()
#     262 # terminate children
#     263 for child in children:
#
# File ~\.conda\envs\torch_cu118\Lib\site-packages\psutil\__init__.py:1268, in Process.wait(self, timeout)
#    1266 if self._exitcode is not _SENTINEL:
#    1267     return self._exitcode
# -> 1268 self._exitcode = self._proc.wait(timeout)
#    1269 return self._exitcode
#
# File ~\.conda\envs\torch_cu118\Lib\site-packages\psutil\_pswindows.py:688, in wrap_exceptions.<locals>.wrapper(self, *args, **kwargs)
#     685 @functools.wraps(fun)
#     686 def wrapper(self, *args, **kwargs):
#     687     try:
# --> 688         return fun(self, *args, **kwargs)
#     689     except OSError as err:
#     690         raise convert_oserror(err, pid=self.pid, name=self._name)
#
# File ~\.conda\envs\torch_cu118\Lib\site-packages\psutil\_pswindows.py:902, in Process.wait(self, timeout)
#     896 stop_at = timer() + timeout if timeout is not None else None
#     898 try:
#     899     # Exit code is supposed to come from GetExitCodeProcess().
#     900     # May also be None if OpenProcess() failed with
#     901     # ERROR_INVALID_PARAMETER, meaning PID is already gone.
# --> 902     exit_code = cext.proc_wait(self.pid, cext_timeout)
#     903 except cext.TimeoutExpired:
#     904     # WaitForSingleObject() returned WAIT_TIMEOUT. Just raise.
#     905     raise TimeoutExpired(timeout, self.pid, self._name)
#
# KeyboardInterrupt:
